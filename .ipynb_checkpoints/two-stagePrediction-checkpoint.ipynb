# %% [markdown]
# #  Two-Stage Prediction Approach

# %% [markdown]
# In this notebook, we implement a two-stage forecasting approach for predicting daily energy consumption. This hybrid method enhances prediction accuracy by leveraging both long-term trends and short-term fluctuations.

# %% [markdown]
# 🔹 Stage 1: Long-Term Trend Prediction
# Objective:
# The first stage aims to capture the macro trends in energy consumption using yearly and monthly data.
#
# Steps:
# 1- Data Aggregation
#
# - Convert daily load consumption data into yearly/monthly averages.
# - Merge with macro factors like GDP, population, energy prices, and renewable energy consumption.
#
# 2- Train a Machine Learning Model
#
# - Model: XGBoost Regressor (or Random Forest)
# - Features: Economic indicators, energy mix, policy changes, etc.
# - Target: Total yearly energy demand.
#
# 3- Predict Long-Term Trends
#
# - The model predicts yearly energy demand.
# - These values are merged with the daily dataset.
#
# 4- Store Predictions
# - The predicted long-term trend is stored as:
#     daily_data["Long_Term_Trend"] = long_term_predictions
# - This column represents the baseline energy demand without short-term fluctuations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()

# %% [markdown]
# ## Preprocessing data

# %% [markdown]
# #### Hourly data

# %%
load_path = 'processed_data/data_2006_2023.csv'

# %%
load_data = pd.read_csv(load_path)

# %%
## to make sure that data is stationary

# Check for stationarity using Augmented Dickey-Fuller test
def adf_test(series):
    result = adfuller(series)
    print(f"ADF Statistic: {result[0]}")
    print(f"p-value: {result[1]}")
    if result[1] < 0.05:
        print("Data is stationary")
    else:
        print("Data is NOT stationary")

# %%
adf_test(load_data["loadConsumption"])
# Out:
# ADF Statistic: -27.204566436886566
# p-value: 0.0
# Data is stationary

# %%
load_data["datetime"] = pd.to_datetime(load_data["datetime"])

load_data.set_index("datetime", inplace=True)

filtered_data = load_data.loc["2015":"2023"]

# %%
filtered_data
# Out:
#                      loadConsumption        date  Hour  Year
# datetime
# 2015-01-01 00:00:00       11338.0000  2015-01-01     1  2015
# 2015-01-01 01:00:00       10917.0000  2015-01-01     2  2015
# 2015-01-01 02:00:00       10473.0000  2015-01-01     3  2015
# 2015-01-01 03:00:00       10200.0000  2015-01-01     4  2015
# 2015-01-01 04:00:00       10182.0000  2015-01-01     5  2015
# ...                              ...         ...   ...   ...
# 2023-12-31 19:00:00       12673.4650  2023-12-31    20  2023
# 2023-12-31 20:00:00       12366.1950  2023-12-31    21  2023
# 2023-12-31 21:00:00       12143.1775  2023-12-31    22  2023
# 2023-12-31 22:00:00       11993.1200  2023-12-31    23  2023
# 2023-12-31 23:00:00       11922.8925  2023-12-31    24  2023
#
# [78883 rows x 4 columns]

# %%
filtered_data['loadConsumption'].plot(
    style='-',
    figsize=(15, 5),
    color=color_pal[0],
    title='Load Consumption (Filtered)'
)
plt.show()

# %% [markdown]
# ### Daily data

# %%
# Resample to daily data using sum
dailyLoad_data = filtered_data.resample("D")["loadConsumption"].sum().reset_index()

# %%
#dailyLoad_data.set_index("date", inplace=True)

# %%
dailyLoad_data
# Out:
#        datetime  loadConsumption
# 0    2015-01-01      286667.0000
# 1    2015-01-02      319584.0000
# 2    2015-01-03      312955.0000
# 3    2015-01-04      296676.0000
# 4    2015-01-05      351510.0000
# ...         ...              ...
# 3282 2023-12-27      305610.2900
# 3283 2023-12-28      326312.3400
# 3284 2023-12-29      314575.3300
# 3285 2023-12-30      290563.1625
# 3286 2023-12-31      296833.7350
#
# [3287 rows x 2 columns]

# %%
# weather data
weather_data_path = 'processed_data/weather.csv' 
weather_data = pd.read_csv(weather_data_path)

# %%
#weather_data.head()

# %%
weather_data["Date"] = pd.to_datetime(weather_data["Date"])
weather_data["Year"] = weather_data["Year"].astype(int)
weather_data = weather_data[weather_data["Year"] >= 2015]

# %%
#weather_data.set_index("Date", inplace=True)

# %%
weather_data
# Out:
#            Date  DailyPrecipitation  MaxHourlyPrecipitation  \
# 3287 2015-01-01                -0.1                    -0.1
# 3288 2015-01-02                 4.3                     1.7
# 3289 2015-01-03                 1.5                     0.5
# 3290 2015-01-04                -0.1                    -0.1
# 3291 2015-01-05                 0.0                     0.0
# ...         ...                 ...                     ...
# 6950 2025-01-11                -0.1                    -0.1
# 6951 2025-01-12                 0.1                     0.1
# 6952 2025-01-13                 0.0                     0.0
# 6953 2025-01-14                 0.1                     0.1
# 6954 2025-01-15                 0.0                     0.0
#
#       HDMaxPrecipitation  DailyMeanTemperature  HourlyMinTemperature  \
# 3287                   1                   3.0                    10
# 3288                   3                   7.3                    44
# 3289                  10                   3.8                    26
# 3290                   1                   3.9                    -3
# 3291                   1                   2.4                     9
# ...                  ...                   ...                   ...
# 6950                   1                   0.5                   -45
# 6951                  21                   1.7                    -6
# 6952                   1                   0.5                   -33
# 6953                  20                   2.8                   -16
# 6954                   1                   6.6                    56
#
#       HDMinTemperature  HourlyMaxTemperature  HDMaxTemperature  \
# 3287                 5                   4.7                24
# 3288                 1                  10.1                 8
# 3289                17                   5.9                 1
# 3290                21                   8.0                13
# 3291                11                   3.8                24
# ...                ...                   ...               ...
# 6950                 8                   5.8                14
# 6951                22                   6.0                14
# 6952                 5                   5.2                14
# 6953                 1                   5.7                24
# 6954                 1                   7.3                17
#
#       DailyMeanWindspeed  MaxHourlyMeanWindspeed  HDMaxMeanWindspeed  \
# 3287                 5.4                     8.0                  24
# 3288                 6.1                     9.0                   2
# 3289                 3.3                     5.0                   7
# 3290                 2.4                     3.0                  11
# 3291                 3.0                     5.0                  11
# ...                  ...                     ...                 ...
# 6950                 1.5                     3.0                  14
# 6951                 1.2                     2.0                   5
# 6952                 2.2                     4.0                  13
# 6953                 3.1                     5.0                  13
# 6954                 1.2                     2.0                   1
#
#       MinHourlyMeanWindspeed  HDMinMeanWindspeed  Month  Year  Week  WeekKey  \
# 3287                     4.0                   1      1  2015     1   201501
# 3288                     4.0                  20      1  2015     1   201501
# 3289                     1.0                  17      1  2015     1   201501
# 3290                     2.0                   1      1  2015     1   201501
# 3291                     1.0                  22      1  2015     2   201502
# ...                      ...                 ...    ...   ...   ...      ...
# 6950                     0.0                   7      1  2025     2   202502
# 6951                     1.0                   1      1  2025     2   202502
# 6952                     1.0                   1      1  2025     3   202503
# 6953                     2.0                   6      1  2025     3   202503
# 6954                     0.0                  19      1  2025     3   202503
#
#      day_of_week
# 3287    Thursday
# 3288      Friday
# 3289    Saturday
# 3290      Sunday
# 3291      Monday
# ...          ...
# 6950    Saturday
# 6951      Sunday
# 6952      Monday
# 6953     Tuesday
# 6954   Wednesday
#
# [3668 rows x 19 columns]

# %%
dailyLoad_data.head()
# Out:
#     datetime  loadConsumption
# 0 2015-01-01         286667.0
# 1 2015-01-02         319584.0
# 2 2015-01-03         312955.0
# 3 2015-01-04         296676.0
# 4 2015-01-05         351510.0

# %%
# Ensure 'date' columns are in datetime format
dailyLoad_data["datetime"] = pd.to_datetime(dailyLoad_data["datetime"])
weather_data["Date"] = pd.to_datetime(weather_data["Date"])

# Set index to 'date' for both DataFrames


# Merge without setting the index
merged_data = dailyLoad_data.merge(weather_data, left_on="datetime", right_on="Date", how="inner")

# Drop redundant date column if necessary
merged_data.drop(columns=["Date"], inplace=True)

# %%
merged_data.to_csv('daily_merged_data.csv', index = False)

# %%
merged_data.head()
# Out:
#     datetime  loadConsumption  DailyPrecipitation  MaxHourlyPrecipitation  \
# 0 2015-01-01         286667.0                -0.1                    -0.1
# 1 2015-01-02         319584.0                 4.3                     1.7
# 2 2015-01-03         312955.0                 1.5                     0.5
# 3 2015-01-04         296676.0                -0.1                    -0.1
# 4 2015-01-05         351510.0                 0.0                     0.0
#
#    HDMaxPrecipitation  DailyMeanTemperature  HourlyMinTemperature  \
# 0                   1                   3.0                    10
# 1                   3                   7.3                    44
# 2                  10                   3.8                    26
# 3                   1                   3.9                    -3
# 4                   1                   2.4                     9
#
#    HDMinTemperature  HourlyMaxTemperature  HDMaxTemperature  \
# 0                 5                   4.7                24
# 1                 1                  10.1                 8
# 2                17                   5.9                 1
# 3                21                   8.0                13
# 4                11                   3.8                24
#
#    DailyMeanWindspeed  MaxHourlyMeanWindspeed  HDMaxMeanWindspeed  \
# 0                 5.4                     8.0                  24
# 1                 6.1                     9.0                   2
# 2                 3.3                     5.0                   7
# 3                 2.4                     3.0                  11
# 4                 3.0                     5.0                  11
#
#    MinHourlyMeanWindspeed  HDMinMeanWindspeed  Month  Year  Week  WeekKey  \
# 0                     4.0                   1      1  2015     1   201501
# 1                     4.0                  20      1  2015     1   201501
# 2                     1.0                  17      1  2015     1   201501
# 3                     2.0                   1      1  2015     1   201501
# 4                     1.0                  22      1  2015     2   201502
#
#   day_of_week
# 0    Thursday
# 1      Friday
# 2    Saturday
# 3      Sunday
# 4      Monday

# %% [markdown]
# ### Monthly Data

# %%
dailyLoad_data = dailyLoad_data.reset_index()

# Extract Year and Month
dailyLoad_data["Year"] = dailyLoad_data["datetime"].dt.year
dailyLoad_data["Month"] = dailyLoad_data["datetime"].dt.month

# Aggregate Load Consumption (Total Monthly)
monthly_load = dailyLoad_data.groupby(["Year", "Month"])["loadConsumption"].sum().reset_index()

# %%
monthly_load
# Out:
#      Year  Month  loadConsumption
# 0    2015      1     1.046155e+07
# 1    2015      2     9.287981e+06
# 2    2015      3     9.705907e+06
# 3    2015      4     8.840250e+06
# 4    2015      5     8.979304e+06
# ..    ...    ...              ...
# 103  2023      8     8.828795e+06
# 104  2023      9     9.033673e+06
# 105  2023     10     9.619636e+06
# 106  2023     11     9.874929e+06
# 107  2023     12     1.057805e+07
#
# [108 rows x 3 columns]

# %%
## https://www.cbs.nl/nl-nl/cijfers/detail/84575NED
ElecSupConsMonthly_path = 'processed_data/ElecSupConsMonthly.csv'

# %%
ElecSupConsMonthly = pd.read_csv(ElecSupConsMonthly_path)

# %%
ElecSupConsMonthly["Month"] = pd.to_datetime(ElecSupConsMonthly["Month"], format="%B").dt.month

# %%
ElecSupConsMonthly.head()
# Out:
#    Year  Month  Gross production (mln kWh)  \
# 0  2015      1                       10700
# 1  2015      2                        9695
# 2  2015      3                        9642
# 3  2015      4                        8602
# 4  2015      5                        7585
#
#    Net production/Net production, total (mln kWh)  \
# 0                                           10301
# 1                                            9328
# 2                                            9302
# 3                                            8216
# 4                                            7248
#
#    Net production/Nuclear energy (mln kWh)  \
# 0                                    364.0
# 1                                    329.0
# 2                                    363.0
# 3                                    345.0
# 4                                    132.0
#
#    Net production/Fuels/Fuels, total (mln kWh)  \
# 0                                         8918
# 1                                         8310
# 2                                         8038
# 3                                         7211
# 4                                         6295
#
#    Net production/Fuels/Coal (mln kWh)  \
# 0                                 3771
# 1                                 3348
# 2                                 3249
# 3                                 3604
# 4                                 2982
#
#    Net production/Fuels/Petroleum products (mln kWh)  \
# 0                                                 96
# 1                                                 79
# 2                                                 49
# 3                                                 53
# 4                                                 97
#
#    Net production/Fuels/Natural gas (mln kWh)  \
# 0                                        4605
# 1                                        4464
# 2                                        4257
# 3                                        3099
# 4                                        2730
#
#    Net production/Fuels/Biomass (mln kWh)  \
# 0                                     349
# 1                                     328
# 2                                     366
# 3                                     342
# 4                                     361
#
#    Net production/Fuels/Other fuels (non-renewable) (mln kWh)  \
# 0                                                 98
# 1                                                 91
# 2                                                118
# 3                                                113
# 4                                                125
#
#    Net production/Hydro power (mln kWh)  \
# 0                                     9
# 1                                    12
# 2                                    13
# 3                                    12
# 4                                    10
#
#    Net production/Wind energy/Wind energy, total (mln kWh)  \
# 0                                                870
# 1                                                504
# 2                                                684
# 3                                                420
# 4                                                564
#
#    Net production/Wind energy/Wind energy on shore (mln kWh)  \
# 0                                                773
# 1                                                440
# 2                                                605
# 3                                                376
# 4                                                499
#
#    Net production/Wind energy/Wind energy off shore (mln kWh)  \
# 0                                                 98
# 1                                                 65
# 2                                                 79
# 3                                                 44
# 4                                                 65
#
#    Net production/Solar photovoltaic (mln kWh)  \
# 0                                           28
# 1                                           58
# 2                                           86
# 3                                          133
# 4                                          152
#
#    Net production/Other sources (mln kWh)  Imports/Imports, total (mln kWh)  \
# 0                                     111                              2432
# 1                                     116                              2371
# 2                                     118                              2729
# 3                                      94                              2414
# 4                                      94                              2782
#
#    Exports/Exports, total (mln kWh)  Net consumption (calculated) (mln kWh)
# 0                              1979                                   10263
# 1                              2110                                    9150
# 2                              2151                                    9427
# 3                              1805                                    8410
# 4                              1094                                    8520

# %%
conversion_factor = 1000

# Identify columns containing 'mln kWh' to convert
columns_to_convert = [col for col in ElecSupConsMonthly.columns if 'mln kWh' in col]

# Apply conversion and rename columns
for col in columns_to_convert:
    ElecSupConsMonthly[col.replace("mln kWh", "MWh")] = ElecSupConsMonthly[col] * conversion_factor

# Drop original columns
ElecSupConsMonthly.drop(columns=columns_to_convert, inplace=True)

# %%
ElecSupConsMonthly.head()
# Out:
#    Year  Month  Gross production (MWh)  \
# 0  2015      1                10700000
# 1  2015      2                 9695000
# 2  2015      3                 9642000
# 3  2015      4                 8602000
# 4  2015      5                 7585000
#
#    Net production/Net production, total (MWh)  \
# 0                                    10301000
# 1                                     9328000
# 2                                     9302000
# 3                                     8216000
# 4                                     7248000
#
#    Net production/Nuclear energy (MWh)  \
# 0                             364000.0
# 1                             329000.0
# 2                             363000.0
# 3                             345000.0
# 4                             132000.0
#
#    Net production/Fuels/Fuels, total (MWh)  Net production/Fuels/Coal (MWh)  \
# 0                                  8918000                          3771000
# 1                                  8310000                          3348000
# 2                                  8038000                          3249000
# 3                                  7211000                          3604000
# 4                                  6295000                          2982000
#
#    Net production/Fuels/Petroleum products (MWh)  \
# 0                                          96000
# 1                                          79000
# 2                                          49000
# 3                                          53000
# 4                                          97000
#
#    Net production/Fuels/Natural gas (MWh)  Net production/Fuels/Biomass (MWh)  \
# 0                                 4605000                              349000
# 1                                 4464000                              328000
# 2                                 4257000                              366000
# 3                                 3099000                              342000
# 4                                 2730000                              361000
#
#    Net production/Fuels/Other fuels (non-renewable) (MWh)  \
# 0                                              98000
# 1                                              91000
# 2                                             118000
# 3                                             113000
# 4                                             125000
#
#    Net production/Hydro power (MWh)  \
# 0                              9000
# 1                             12000
# 2                             13000
# 3                             12000
# 4                             10000
#
#    Net production/Wind energy/Wind energy, total (MWh)  \
# 0                                             870000
# 1                                             504000
# 2                                             684000
# 3                                             420000
# 4                                             564000
#
#    Net production/Wind energy/Wind energy on shore (MWh)  \
# 0                                             773000
# 1                                             440000
# 2                                             605000
# 3                                             376000
# 4                                             499000
#
#    Net production/Wind energy/Wind energy off shore (MWh)  \
# 0                                              98000
# 1                                              65000
# 2                                              79000
# 3                                              44000
# 4                                              65000
#
#    Net production/Solar photovoltaic (MWh)  \
# 0                                    28000
# 1                                    58000
# 2                                    86000
# 3                                   133000
# 4                                   152000
#
#    Net production/Other sources (MWh)  Imports/Imports, total (MWh)  \
# 0                              111000                       2432000
# 1                              116000                       2371000
# 2                              118000                       2729000
# 3                               94000                       2414000
# 4                               94000                       2782000
#
#    Exports/Exports, total (MWh)  Net consumption (calculated) (MWh)
# 0                       1979000                            10263000
# 1                       2110000                             9150000
# 2                       2151000                             9427000
# 3                       1805000                             8410000
# 4                       1094000                             8520000

# %%
nao_path = 'processed_data/nao.csv'

# %%
nao = pd.read_csv(nao_path)

# %%
nao["Year"] = nao["Year"].astype(int)

# Filter for Year >= 2015
nao = nao[nao["Year"] >= 2015]

# %%
nao
# Out:
#      Year  Month   NAO
# 108  2015      1  1.79
# 109  2015      2  1.32
# 110  2015      3  1.45
# 111  2015      4  0.73
# 112  2015      5  0.15
# ..    ...    ...   ...
# 223  2024      8  0.63
# 224  2024      9 -1.43
# 225  2024     10 -0.38
# 226  2024     11 -0.23
# 227  2024     12  1.21
#
# [120 rows x 3 columns]

# %%
# Ensure 'Year' and 'Month' are integers in both DataFrames
ElecSupConsMonthly["Year"] = ElecSupConsMonthly["Year"].astype(int)
ElecSupConsMonthly["Month"] = ElecSupConsMonthly["Month"].astype(int)

nao["Year"] = nao["Year"].astype(int)
nao["Month"] = nao["Month"].astype(int)

# Merge on 'Year' and 'Month'
merged_monthly_data = pd.merge(ElecSupConsMonthly, nao, on=["Year", "Month"], how="inner")
merged_monthly_data = pd.merge(merged_monthly_data, monthly_load, on=["Year", "Month"], how="inner")

# %%
merged_monthly_data
# Out:
#     Year  Month  Gross production (MWh)  \
# 0   2015      1                10700000
# 1   2015      2                 9695000
# 2   2015      3                 9642000
# 3   2015      4                 8602000
# 4   2015      5                 7585000
# ..   ...    ...                     ...
# 91  2022      8                10408000
# 92  2022      9                 9721000
# 93  2022     10                 9764000
# 94  2022     11                 9290000
# 95  2022     12                11072000
#
#     Net production/Net production, total (MWh)  \
# 0                                     10301000
# 1                                      9328000
# 2                                      9302000
# 3                                      8216000
# 4                                      7248000
# ..                                         ...
# 91                                    10088000
# 92                                     9392000
# 93                                     9471000
# 94                                     8987000
# 95                                    10725000
#
#     Net production/Nuclear energy (MWh)  \
# 0                              364000.0
# 1                              329000.0
# 2                              363000.0
# 3                              345000.0
# 4                              132000.0
# ..                                  ...
# 91                             345000.0
# 92                             338000.0
# 93                             355000.0
# 94                             346000.0
# 95                             361000.0
#
#     Net production/Fuels/Fuels, total (MWh)  Net production/Fuels/Coal (MWh)  \
# 0                                   8918000                          3771000
# 1                                   8310000                          3348000
# 2                                   8038000                          3249000
# 3                                   7211000                          3604000
# 4                                   6295000                          2982000
# ..                                      ...                              ...
# 91                                  6443000                          1597000
# 92                                  6141000                          1928000
# 93                                  6024000                          1265000
# 94                                  5415000                          1236000
# 95                                  7789000                          1700000
#
#     Net production/Fuels/Petroleum products (MWh)  \
# 0                                           96000
# 1                                           79000
# 2                                           49000
# 3                                           53000
# 4                                           97000
# ..                                            ...
# 91                                         147000
# 92                                         133000
# 93                                         106000
# 94                                         106000
# 95                                         144000
#
#     Net production/Fuels/Natural gas (MWh)  \
# 0                                  4605000
# 1                                  4464000
# 2                                  4257000
# 3                                  3099000
# 4                                  2730000
# ..                                     ...
# 91                                 3719000
# 92                                 3218000
# 93                                 4038000
# 94                                 3199000
# 95                                 5079000
#
#     Net production/Fuels/Biomass (MWh)  ...  \
# 0                               349000  ...
# 1                               328000  ...
# 2                               366000  ...
# 3                               342000  ...
# 4                               361000  ...
# ..                                 ...  ...
# 91                              831000  ...
# 92                              734000  ...
# 93                              488000  ...
# 94                              755000  ...
# 95                              745000  ...
#
#     Net production/Wind energy/Wind energy, total (MWh)  \
# 0                                              870000
# 1                                              504000
# 2                                              684000
# 3                                              420000
# 4                                              564000
# ..                                                ...
# 91                                             877000
# 92                                            1351000
# 93                                            2065000
# 94                                            2700000
# 95                                            2277000
#
#     Net production/Wind energy/Wind energy on shore (MWh)  \
# 0                                              773000
# 1                                              440000
# 2                                              605000
# 3                                              376000
# 4                                              499000
# ..                                                ...
# 91                                             518000
# 92                                             768000
# 93                                            1294000
# 94                                            1710000
# 95                                            1381000
#
#     Net production/Wind energy/Wind energy off shore (MWh)  \
# 0                                               98000
# 1                                               65000
# 2                                               79000
# 3                                               44000
# 4                                               65000
# ..                                                ...
# 91                                             360000
# 92                                             583000
# 93                                             771000
# 94                                             991000
# 95                                             896000
#
#     Net production/Solar photovoltaic (MWh)  \
# 0                                     28000
# 1                                     58000
# 2                                     86000
# 3                                    133000
# 4                                    152000
# ..                                      ...
# 91                                  2373000
# 92                                  1515000
# 93                                   977000
# 94                                   478000
# 95                                   250000
#
#     Net production/Other sources (MWh)  Imports/Imports, total (MWh)  \
# 0                               111000                       2432000
# 1                               116000                       2371000
# 2                               118000                       2729000
# 3                                94000                       2414000
# 4                                94000                       2782000
# ..                                 ...                           ...
# 91                               50000                       1029000
# 92                               46000                       1207000
# 93                               50000                       1736000
# 94                               47000                       2150000
# 95                               46000                       1513000
#
#     Exports/Exports, total (MWh)  Net consumption (calculated) (MWh)   NAO  \
# 0                        1979000                            10263000  1.79
# 1                        2110000                             9150000  1.32
# 2                        2151000                             9427000  1.45
# 3                        1805000                             8410000  0.73
# 4                        1094000                             8520000  0.15
# ..                           ...                                 ...   ...
# 91                       1725000                             9019000  1.47
# 92                       1686000                             8528000 -1.61
# 93                       2162000                             8627000 -0.72
# 94                       1868000                             8841000  0.69
# 95                       2145000                             9646000 -0.15
#
#     loadConsumption
# 0      1.046155e+07
# 1      9.287981e+06
# 2      9.705907e+06
# 3      8.840250e+06
# 4      8.979304e+06
# ..              ...
# 91     7.858605e+06
# 92     7.905307e+06
# 93     8.248071e+06
# 94     8.812078e+06
# 95     9.676477e+06
#
# [96 rows x 22 columns]

# %%
merged_monthly_data.to_csv('merged_monthyl_data.csv', index = False)

# %% [markdown]
# ### Quartal data

# %%
gdp_path = 'processed_data/GDP.csv'

# %%
gdp = pd.read_csv(gdp_path)

# %%
gdp["Year"] = gdp["Year"].astype(int)

# Filter for Year >= 2015
gdp = gdp[gdp["Year"] >= 2015]

# %%
gdp.head()
# Out:
#         Period       GDP  Year
# 36  2015-01-01  171938.0  2015
# 37  2015-04-01  174143.8  2015
# 38  2015-07-01  176415.0  2015
# 39  2015-10-01  176716.6  2015
# 40  2016-01-01  177498.0  2016

# %% [markdown]
# ### Half Year data

# %%
### gdp into half yearly data

# Convert 'Period' to datetime format
gdp["Period"] = pd.to_datetime(gdp["Period"])

# Extract Year and assign Half-Year (H1: Jan-Jun, H2: Jul-Dec)
gdp["Year"] = gdp["Period"].dt.year
gdp["Half_Year"] = gdp["Period"].dt.month.apply(lambda x: 'H1' if x <= 6 else 'H2')

# Aggregate data to half-yearly resolution
gdp_half_year = gdp.groupby(["Year", "Half_Year"])["GDP"].mean().reset_index()

# Create a new column to represent the half-year period
gdp_half_year["Period"] = gdp_half_year["Year"].astype(str) + "-" + gdp_half_year["Half_Year"]

# Display result
gdp_half_year.head()
# Out:
#    Year Half_Year        GDP   Period
# 0  2015        H1  173040.90  2015-H1
# 1  2015        H2  176565.80  2015-H2
# 2  2016        H1  178289.05  2016-H1
# 3  2016        H2  181875.65  2016-H2
# 4  2017        H1  185755.90  2017-H1

# %%
energyPrice_path = 'processed_data/energyPrice.csv'

# %%
energyPrice = pd.read_csv(energyPrice_path)

# %%
energyPrice["Year"] = energyPrice["Year"].astype(int)

# Filter for Year >= 2015
energyPrice = energyPrice[energyPrice["Year"] >= 2015]

# %%
energyPrice.head()
# Out:
#     Year PriceComponents           Periods  \
# 18  2015      TotalPrice  2015 1e halfjaar
# 19  2015      TotalPrice  2015 2e halfjaar
# 20  2015      TotalPrice              2015
# 21  2016      TotalPrice  2016 1e halfjaar
# 22  2016      TotalPrice  2016 2e halfjaar
#
#     NG_Household_LessThan_569m3_EuroPerM3  NG_Household_569to5687m3_EuroPerM3  \
# 18                                  1.037                               0.739
# 19                                  1.312                               0.784
# 20                                  1.139                               0.755
# 21                                  1.063                               0.762
# 22                                  1.277                               0.790
#
#     NG_Household_MoreThan_5687m3_EuroPerM3  \
# 18                                   0.680
# 19                                   0.678
# 20                                   0.673
# 21                                   0.698
# 22                                   0.696
#
#     NG_NonHousehold_LessThan_28433m3_EuroPerM3  \
# 18                                       0.715
# 19                                       0.719
# 20                                       0.717
# 21                                       0.750
# 22                                       0.751
#
#     NG_NonHousehold_28433to284333m3_EuroPerM3  \
# 18                                      0.648
# 19                                      0.670
# 20                                      0.657
# 21                                      0.684
# 22                                      0.667
#
#     NG_NonHousehold_284333to2843332m3_EuroPerM3  \
# 18                                        0.460
# 19                                        0.379
# 20                                        0.430
# 21                                        0.453
# 22                                        0.340
#
#     NG_NonHousehold_2843332to28433324m3_EuroPerM3  ...  \
# 18                                          0.360  ...
# 19                                          0.312  ...
# 20                                          0.339  ...
# 21                                          0.303  ...
# 22                                          0.286  ...
#
#     Electricity_NonHousehold_20to500MWh_EuroPerKWh  \
# 18                                           0.173
# 19                                           0.128
# 20                                           0.151
# 21                                           0.168
# 22                                           0.123
#
#     Electricity_NonHousehold_500to2000MWh_EuroPerKWh  \
# 18                                             0.110
# 19                                             0.103
# 20                                             0.106
# 21                                             0.105
# 22                                             0.097
#
#     Electricity_NonHousehold_2000to20000MWh_EuroPerKWh  \
# 18                                              0.099
# 19                                              0.097
# 20                                              0.098
# 21                                              0.093
# 22                                              0.093
#
#     Electricity_NonHousehold_20000to70000MWh_EuroPerKWh  \
# 18                                              0.086
# 19                                              0.077
# 20                                              0.081
# 21                                              0.079
# 22                                              0.071
#
#     Electricity_NonHousehold_70000to150000MWh_EuroPerKWh  \
# 18                                              0.086
# 19                                              0.081
# 20                                              0.084
# 21                                              0.074
# 22                                              0.071
#
#     Electricity_NonHousehold_MoreThan_150000MWh_EuroPerKWh  \
# 18                                              0.081
# 19                                              0.078
# 20                                              0.079
# 21                                              0.070
# 22                                              0.071
#
#     AveragePrice_Electricity_Household  AveragePrice_Electricity_NonHousehold  \
# 18                              0.1604                               0.122143
# 19                              0.1240                               0.111143
# 20                              0.1400                               0.116571
# 21                              0.1168                               0.111143
# 22                              0.1080                               0.100714
#
#     AveragePrice_NaturalGas_Household  AveragePrice_NaturalGas_NonHousehold
# 18                           0.818667                                0.4962
# 19                           0.924667                                0.4690
# 20                           0.855667                                0.4852
# 21                           0.841000                                0.4808
# 22                           0.921000                                0.4528
#
# [5 rows x 27 columns]

# %%
energyPrice["Half_Year"] = energyPrice["Periods"].replace({"1e halfjaar": "H1", "2e halfjaar": "H2"})

# Convert energy price "Year" column to integer
energyPrice["Year"] = energyPrice["Periods"].str.extract(r'(\d{4})').astype(int)

# Merge GDP and Energy Price Data
merged_halYear_data = pd.merge(gdp, energyPrice, on=["Year", "Half_Year"], how="inner")

# %%
merged_halYear_data.to_csv('merged_halYear_data.csv', index = False)

# %% [markdown]
# ### Yearly Data

# %%
#dailyLoad_data.head()

# %%
if "datetime" not in dailyLoad_data.columns:
    dailyLoad_data = dailyLoad_data.reset_index()

# Convert 'date' to datetime format
dailyLoad_data["datetime"] = pd.to_datetime(dailyLoad_data["datetime"])

# Extract Year
dailyLoad_data["Year"] = dailyLoad_data["datetime"].dt.year

# Aggregate Load Consumption to Yearly (Total or Average)
yearly_load = dailyLoad_data.groupby("Year")["loadConsumption"].sum().reset_index()

# %%
yearly_load
# Out:
#    Year  loadConsumption
# 0  2015     1.132386e+08
# 1  2016     1.145306e+08
# 2  2017     1.150203e+08
# 3  2018     1.165233e+08
# 4  2019     1.139243e+08
# 5  2020     1.081375e+08
# 6  2021     1.063768e+08
# 7  2022     1.003770e+08
# 8  2023     1.091857e+08

# %%
elecBalance_path = 'processed_data/elecBalance.csv'

# %%
elecBalance = pd.read_csv(elecBalance_path)

# %%
# Convert all columns from PJ to MWh (1 PJ = 277,778 MWh)
conversion_factor = 277778

# Identify columns containing 'PJ' to convert
columns_to_convert = [col for col in elecBalance.columns if '(PJ)' in col]

# Apply conversion and rename columns
for col in columns_to_convert:
    elecBalance[col.replace("(PJ)", "(MWh)")] = elecBalance[col] * conversion_factor

# Drop original columns
elecBalance.drop(columns=columns_to_convert, inplace=True)

# %%
### consumption of electricity by orginal source?

# %%
elecBalance.head()
# Out:
#    Year  Commercial and public services (MWh)  \
# 0  2006                          3.462703e+07
# 1  2007                          3.541703e+07
# 2  2008                          3.588903e+07
# 3  2009                          3.654703e+07
# 4  2010                          3.676603e+07
#
#    Electricity, CHP and heat plants (MWh)  Exports (MWh)  Imports (MWh)  \
# 0                            9.883308e+07  -5.887005e+06   2.734602e+07
# 1                            1.051661e+08  -5.480005e+06   2.308902e+07
# 2                            1.075521e+08  -9.116007e+06   2.496702e+07
# 3                            1.136901e+08  -1.056101e+07   1.545201e+07
# 4                            1.192691e+08  -1.280801e+07   1.558301e+07
#
#    Industry (MWh)  Oil refineries, transformation (MWh)  \
# 0    4.150914e+07                                     0
# 1    4.217803e+07                                     0
# 2    4.188160e+07                                     0
# 3    3.647583e+07                                     0
# 4    3.910208e+07                                     0
#
#    Other final consumption (MWh)  Production (MWh)  Residential (MWh)  \
# 0                   5.745005e+06                 0       2.208102e+07
# 1                   6.298005e+06                 0       2.226802e+07
# 2                   6.528006e+06                 0       2.250102e+07
# 3                   7.083006e+06                 0       2.287202e+07
# 4                   7.024006e+06                 0       2.299402e+07
#
#    Total energy supply (MWh)  Total final consumption (MWh)  Transport (MWh)
# 0               2.145902e+07                   1.055762e+08     1.614001e+06
# 1               1.760901e+07                   1.077511e+08     1.590001e+06
# 2               1.585101e+07                   1.084237e+08     1.624002e+06
# 3               4.891004e+06                   1.046559e+08     1.678001e+06
# 4               2.775003e+06                   1.076421e+08     1.756001e+06

# %%
elecBalance["Year"] = elecBalance["Year"].astype(int)

# Filter for Year >= 2015
elecBalance = elecBalance[elecBalance["Year"] >= 2015]

# %%
population_path = 'processed_data/populationNL.csv'

# %%
populationNL = pd.read_csv(population_path)

# %%
populationNL["Year"] = populationNL["Year"].astype(int)

# Filter for Year >= 2015
populationNL = populationNL[populationNL["Year"] >= 2015]

# %%
populationNL
# Out:
#     Year Population
# 9   2015      16,90
# 10  2016      16,98
# 11  2017      17,08
# 12  2018      17,18
# 13  2019      17,28
# 14  2020      17,41
# 15  2021      17,48
# 16  2022      17,59
# 17  2023      17,81

# %%
res_path = 'processed_data/renwableEnergy.csv'

# %%
rEnergy = pd.read_csv(res_path)

# %%
# Convert all columns from TJ to MWh (1 TJ = 277.78 MWh)
conversion_factor = 277.78

# Identify columns containing energy values (assuming all except "Year")
columns_to_convert = [col for col in rEnergy.columns if col != "Year"]

# Apply conversion and rename columns
for col in columns_to_convert:
    rEnergy[col + " (MWh)"] = rEnergy[col] * conversion_factor

# Drop original columns
rEnergy.drop(columns=columns_to_convert, inplace=True)

# %%
rEnergy["Year"] = rEnergy["Year"].astype(int)

# Filter for Year >= 2015
rEnergy = rEnergy[rEnergy["Year"] >= 2015]

# %%
### production of renewable energy per source?

# %%
rEnergy
# Out:
#     Year  GeothermalHeat (MWh)  AmbientAirHeat (MWh)  \
# 9   2015            1009452.52             560837.82
# 10  2016            1070841.90             731950.30
# 11  2017            1133620.18             980285.62
# 12  2018            1217509.74            1296677.04
# 13  2019            1309732.70            1713069.26
# 14  2020            1415844.66            2225573.36
# 15  2021            1533345.60            2918634.46
# 16  2022            1662235.52            3941975.98
# 17  2023            1849181.46            5240875.26
#
#     TotalGeothermal&GroundEnergy (MWh)  TotalBiomass (MWh)  \
# 9                           1689457.96         21863230.46
# 10                          1860848.22         20963778.82
# 11                          1979738.06         22786015.62
# 12                          2253906.92         25712983.48
# 13                          2855300.62         30123852.10
# 14                          3133913.96         33456934.32
# 15                          3290859.66         35205837.20
# 16                          3550861.74         30623578.32
# 17                          3737529.90         29222456.00
#
#     TotalRes(excl.Stat.Transfer) (MWh)  TotalRes(incl.Stat.Transfer) (MWh)  \
# 9                          32553593.76                         32553593.76
# 10                         33938327.06                         33938327.06
# 11                         38004470.70                         38004470.70
# 12                         43418125.12                         43418125.12
# 13                         51287076.96                         51287076.96
# 14                         61949106.70                         75599215.90
# 15                         72131410.38                         72131410.38
# 16                         76588390.48                         76588390.48
# 17                         85044291.46                         85044291.46
#
#     Totaal windenergie (MWh)  TotalSolarEnergy (MWh)  \
# 9                 6916722.00              1424178.06
# 10                8363955.80              1920293.14
# 11                9641743.80              2522242.40
# 12               10029524.68              4030587.80
# 13               10773419.52              5726990.26
# 14               13948722.70              9091461.62
# 15               18998485.32             11627315.24
# 16               21404060.12             16981246.96
# 17               26854103.72             19904881.46
#
#     Total Including Non-Renewable (MWh)  Hydropower (MWh)  \
# 9                          5.684820e+08          98611.90
# 10                         5.809183e+08          97500.78
# 11                         5.846283e+08          94167.42
# 12                         5.878072e+08          94445.20
# 13                         5.771168e+08          92778.52
# 14                         5.400543e+08          90000.72
# 15                         5.567658e+08          90556.28
# 16                         5.139616e+08          86667.36
# 17                         4.957576e+08          84445.12
#
#     OnshoreWindEnergy (MWh)  OffshoreWindEnergy (MWh)  SolarPower (MWh)  \
# 9                5881713.72                1035286.06        1108619.98
# 10               6041159.44                2322796.36        1601957.26
# 11               6266716.80                3375027.00        2204462.08
# 12               6578108.18                3451694.28        3709474.12
# 13               7428670.54                3344748.98        5399209.86
# 14               8962293.92                4986428.78        8764792.34
# 15              10454250.30                8544235.02       11303979.32
# 16              12956770.32                8447289.80       16656799.92
# 17              15767348.36               11086755.36       19578212.18
#
#     SolarThermalEnergy (MWh)
# 9                  315835.86
# 10                 318613.66
# 11                 317780.32
# 12                 321113.68
# 13                 327780.40
# 14                 326669.28
# 15                 323335.92
# 16                 324447.04
# 17                 326669.28

# %%
resedential_path = 'processed_data/resedentialEnergyData(Provincies).csv'

# %%
resedentialData = pd.read_csv(resedential_path)

# %%
# Correcting the column name typo and applying the conversion
corrected_column_name = "AvgElectricitySupplyResedential"  

# Convert from kWh to MWh (1 kWh = 0.001 MWh)
resedentialData['AvgElectricitySupplyResedential (MWh)'] = resedentialData[corrected_column_name] * 0.001

# Drop the original kWh column
resedentialData.drop(columns=[corrected_column_name], inplace=True)

# %%
resedentialData["Year"] = resedentialData["Year"].astype(int)

# Filter for Year >= 2015
resedentialData = resedentialData[resedentialData["Year"] >= 2015]

# %%
resedentialData
# Out:
#     Housing characteristics  Year          Regions  \
# 5           Total dwellings  2015  The Netherlands
# 6           Total dwellings  2016  The Netherlands
# 7           Total dwellings  2017  The Netherlands
# 8           Total dwellings  2018  The Netherlands
# 9           Total dwellings  2019  The Netherlands
# ..                      ...   ...              ...
# 502    Owner-occupied house  2018     Limburg (PV)
# 503    Owner-occupied house  2019     Limburg (PV)
# 504    Owner-occupied house  2020     Limburg (PV)
# 505    Owner-occupied house  2021     Limburg (PV)
# 506    Owner-occupied house  2022     Limburg (PV)
#
#      AvgGasConsumptionResedetial  AvgElectricitySupplyResedential (MWh)
# 5                         1250.0                                   2.98
# 6                         1300.0                                   2.91
# 7                         1240.0                                   2.86
# 8                         1270.0                                   2.79
# 9                         1180.0                                   2.73
# ..                           ...                                    ...
# 502                       1680.0                                   3.49
# 503                       1560.0                                   3.36
# 504                       1460.0                                   3.35
# 505                       1660.0                                   3.41
# 506                       1300.0                                   3.22
#
# [312 rows x 5 columns]

# %%
resedentialData.columns
# Out:
# Index(['Housing characteristics', 'Year', 'Regions',
#        'AvgGasConsumptionResedetial', 'AvgElectricitySupplyResedential (MWh)'],
#       dtype='object')

# %%
# Pivot the dataset to create separate columns for each region
residential_pivot = resedentialData.pivot_table(
    index="Year",
    columns="Regions",
    values=["AvgGasConsumptionResedetial", "AvgElectricitySupplyResedential (MWh)"],
    aggfunc="mean"
)

# Flatten multi-index column names
residential_pivot.columns = [f"{col[0]}_{col[1]}" for col in residential_pivot.columns]
residential_pivot.reset_index(inplace=True)

residential_pivot
# Out:
#    Year  AvgElectricitySupplyResedential (MWh)_Drenthe (PV)  \
# 0  2015                                           2.870000
# 1  2016                                           2.803333
# 2  2017                                           2.743333
# 3  2018                                           2.686667
# 4  2019                                           2.603333
# 5  2020                                           2.640000
# 6  2021                                           2.696667
# 7  2022                                           2.570000
#
#    AvgElectricitySupplyResedential (MWh)_Flevoland (PV)  \
# 0                                           3.023333
# 1                                           2.903333
# 2                                           2.826667
# 3                                           2.736667
# 4                                           2.733333
# 5                                           2.810000
# 6                                           2.836667
# 7                                           2.693333
#
#    AvgElectricitySupplyResedential (MWh)_Fryslân (PV)  \
# 0                                           2.550000
# 1                                           2.463333
# 2                                           2.400000
# 3                                           2.336667
# 4                                           2.373333
# 5                                           2.463333
# 6                                           2.523333
# 7                                           2.390000
#
#    AvgElectricitySupplyResedential (MWh)_Gelderland (PV)  \
# 0                                           2.953333
# 1                                           2.846667
# 2                                           2.773333
# 3                                           2.690000
# 4                                           2.683333
# 5                                           2.756667
# 6                                           2.803333
# 7                                           2.656667
#
#    AvgElectricitySupplyResedential (MWh)_Groningen (PV)  \
# 0                                           2.650000
# 1                                           2.586667
# 2                                           2.533333
# 3                                           2.476667
# 4                                           2.376667
# 5                                           2.430000
# 6                                           2.480000
# 7                                           2.353333
#
#    AvgElectricitySupplyResedential (MWh)_Limburg (PV)  \
# 0                                           2.990000
# 1                                           2.930000
# 2                                           2.893333
# 3                                           2.836667
# 4                                           2.746667
# 5                                           2.746667
# 6                                           2.790000
# 7                                           2.660000
#
#    AvgElectricitySupplyResedential (MWh)_Noord-Brabant (PV)  \
# 0                                           3.073333
# 1                                           3.010000
# 2                                           2.970000
# 3                                           2.920000
# 4                                           2.826667
# 5                                           2.840000
# 6                                           2.883333
# 7                                           2.720000
#
#    AvgElectricitySupplyResedential (MWh)_Noord-Holland (PV)  \
# 0                                           2.706667
# 1                                           2.643333
# 2                                           2.590000
# 3                                           2.530000
# 4                                           2.493333
# 5                                           2.530000
# 6                                           2.586667
# 7                                           2.423333
#
#    AvgElectricitySupplyResedential (MWh)_Overijssel (PV)  ...  \
# 0                                           2.950000      ...
# 1                                           2.876667      ...
# 2                                           2.823333      ...
# 3                                           2.763333      ...
# 4                                           2.680000      ...
# 5                                           2.716667      ...
# 6                                           2.783333      ...
# 7                                           2.640000      ...
#
#    AvgGasConsumptionResedetial_Gelderland (PV)  \
# 0                                  1300.000000
# 1                                  1340.000000
# 2                                  1296.666667
# 3                                  1290.000000
# 4                                  1186.666667
# 5                                  1133.333333
# 6                                  1276.666667
# 7                                  1010.000000
#
#    AvgGasConsumptionResedetial_Groningen (PV)  \
# 0                                 1423.333333
# 1                                 1490.000000
# 2                                 1406.666667
# 3                                 1426.666667
# 4                                 1286.666667
# 5                                 1240.000000
# 6                                 1380.000000
# 7                                 1080.000000
#
#    AvgGasConsumptionResedetial_Limburg (PV)  \
# 0                               1343.333333
# 1                               1396.666667
# 2                               1343.333333
# 3                               1336.666667
# 4                               1246.666667
# 5                               1176.666667
# 6                               1330.000000
# 7                               1046.666667
#
#    AvgGasConsumptionResedetial_Noord-Brabant (PV)  \
# 0                                     1220.000000
# 1                                     1253.333333
# 2                                     1206.666667
# 3                                     1213.333333
# 4                                     1126.666667
# 5                                     1073.333333
# 6                                     1200.000000
# 7                                      940.000000
#
#    AvgGasConsumptionResedetial_Noord-Holland (PV)  \
# 0                                     1130.000000
# 1                                     1170.000000
# 2                                     1116.666667
# 3                                     1126.666667
# 4                                     1043.333333
# 5                                      993.333333
# 6                                     1123.333333
# 7                                      876.666667
#
#    AvgGasConsumptionResedetial_Overijssel (PV)  \
# 0                                  1283.333333
# 1                                  1313.333333
# 2                                  1276.666667
# 3                                  1280.000000
# 4                                  1163.333333
# 5                                  1123.333333
# 6                                  1296.666667
# 7                                  1023.333333
#
#    AvgGasConsumptionResedetial_The Netherlands  \
# 0                                  1190.000000
# 1                                  1233.333333
# 2                                  1183.333333
# 3                                  1193.333333
# 4                                  1106.666667
# 5                                  1056.666667
# 6                                  1186.666667
# 7                                   930.000000
#
#    AvgGasConsumptionResedetial_Utrecht (PV)  \
# 0                               1070.000000
# 1                               1120.000000
# 2                               1066.666667
# 3                               1066.666667
# 4                                986.666667
# 5                                950.000000
# 6                               1066.666667
# 7                                833.333333
#
#    AvgGasConsumptionResedetial_Zeeland (PV)  \
# 0                               1216.666667
# 1                               1236.666667
# 2                               1170.000000
# 3                               1193.333333
# 4                               1113.333333
# 5                               1073.333333
# 6                               1220.000000
# 7                                966.666667
#
#    AvgGasConsumptionResedetial_Zuid-Holland (PV)
# 0                                    1076.666667
# 1                                    1106.666667
# 2                                    1063.333333
# 3                                    1073.333333
# 4                                     996.666667
# 5                                     956.666667
# 6                                    1076.666667
# 7                                     836.666667
#
# [8 rows x 27 columns]

# %%
YearlyFinalCons_path = 'processed_data/yearlyfinalConsPerSource.csv'

# %%
YearlyFinalCons = pd.read_csv(YearlyFinalCons_path)

# %%
# Convert all columns from PJ to MWh (1 PJ = 277,778 MWh)
conversion_factor = 277778

# Identify columns containing energy values (assuming all except "Year")
columns_to_convert = [col for col in YearlyFinalCons.columns if col != "Year"]

# Apply conversion and rename columns
for col in columns_to_convert:
    YearlyFinalCons[col + " (MWh)"] = YearlyFinalCons[col] * conversion_factor

# Drop the original PJ columns
YearlyFinalCons.drop(columns=columns_to_convert, inplace=True)

# %%
 YearlyFinalCons["Year"] = YearlyFinalCons["Year"].astype(int)

# Filter for Year >= 2015
YearlyFinalCons = YearlyFinalCons[YearlyFinalCons["Year"] >= 2015]

# %%
### Final consumption of each source

# %%
YearlyFinalCons
# Out:
#     Year  Crude, NGL and feedstocks (MWh)  Electricity (MWh)    Heat (MWh)  \
# 9   2015                     2.561924e+07       1.036768e+08  2.634479e+07
# 10  2016                     2.678760e+07       1.046485e+08  2.579003e+07
# 11  2017                     2.518568e+07       1.058181e+08  2.451098e+07
# 12  2018                     2.032454e+07       1.078638e+08  2.330076e+07
# 13  2019                     1.707783e+07       1.076402e+08  2.414097e+07
# 14  2020                     1.891350e+07       1.063510e+08  2.208057e+07
# 15  2021                     1.667307e+07       1.067559e+08  2.330489e+07
# 16  2022                     1.741601e+07       1.037859e+08  2.127010e+07
#
#     Natural gas (MWh)  Oil products (MWh)  Renewables and waste (MWh)  \
# 9        2.247547e+08        2.478791e+08                1.408313e+07
# 10       2.300846e+08        2.593781e+08                1.352092e+07
# 11       2.331301e+08        2.690828e+08                1.489403e+07
# 12       2.279023e+08        2.674885e+08                1.868505e+07
# 13       2.241073e+08        2.539378e+08                2.073531e+07
# 14       2.136106e+08        2.505897e+08                1.998465e+07
# 15       2.300143e+08        2.478729e+08                2.081999e+07
# 16       1.799323e+08        2.281547e+08                1.998440e+07
#
#      Total (MWh)
# 9   6.483023e+08
# 10  6.668403e+08
# 11  6.800887e+08
# 12  6.720822e+08
# 13  6.545552e+08
# 14  6.366558e+08
# 15  6.502021e+08
# 16  5.757271e+08

# %%
energyPrice_yearly = energyPrice[energyPrice["Periods"].astype(str).str.isnumeric()]

# Display the first few rows
energyPrice_yearly.head()
# Out:
#     Year PriceComponents Periods  NG_Household_LessThan_569m3_EuroPerM3  \
# 20  2015      TotalPrice    2015                                  1.139
# 23  2016      TotalPrice    2016                                  1.142
# 26  2017      TotalPrice    2017                                  1.200
# 29  2018      TotalPrice    2018                                  1.227
# 32  2019      TotalPrice    2019                                  1.376
#
#     NG_Household_569to5687m3_EuroPerM3  \
# 20                               0.755
# 23                               0.771
# 26                               0.766
# 29                               0.808
# 32                               0.922
#
#     NG_Household_MoreThan_5687m3_EuroPerM3  \
# 20                                   0.673
# 23                                   0.696
# 26                                   0.668
# 29                                   0.709
# 32                                   0.818
#
#     NG_NonHousehold_LessThan_28433m3_EuroPerM3  \
# 20                                       0.717
# 23                                       0.749
# 26                                       0.739
# 29                                       0.755
# 32                                       0.845
#
#     NG_NonHousehold_28433to284333m3_EuroPerM3  \
# 20                                      0.657
# 23                                      0.676
# 26                                      0.651
# 29                                      0.670
# 32                                      0.725
#
#     NG_NonHousehold_284333to2843332m3_EuroPerM3  \
# 20                                        0.430
# 23                                        0.407
# 26                                        0.381
# 29                                        0.408
# 32                                        0.407
#
#     NG_NonHousehold_2843332to28433324m3_EuroPerM3  ...  \
# 20                                          0.339  ...
# 23                                          0.295  ...
# 26                                          0.286  ...
# 29                                          0.303  ...
# 32                                          0.280  ...
#
#     Electricity_NonHousehold_500to2000MWh_EuroPerKWh  \
# 20                                             0.106
# 23                                             0.102
# 26                                             0.095
# 29                                             0.101
# 32                                             0.111
#
#     Electricity_NonHousehold_2000to20000MWh_EuroPerKWh  \
# 20                                              0.098
# 23                                              0.093
# 26                                              0.093
# 29                                              0.095
# 32                                              0.104
#
#     Electricity_NonHousehold_20000to70000MWh_EuroPerKWh  \
# 20                                              0.081
# 23                                              0.075
# 26                                              0.069
# 29                                              0.073
# 32                                              0.078
#
#     Electricity_NonHousehold_70000to150000MWh_EuroPerKWh  \
# 20                                              0.084
# 23                                              0.072
# 26                                              0.064
# 29                                              0.070
# 32                                              0.072
#
#     Electricity_NonHousehold_MoreThan_150000MWh_EuroPerKWh  \
# 20                                              0.079
# 23                                              0.070
# 26                                              0.065
# 29                                              0.067
# 32                                              0.072
#
#     AveragePrice_Electricity_Household  AveragePrice_Electricity_NonHousehold  \
# 20                              0.1400                               0.116571
# 23                              0.1122                               0.105857
# 26                              0.1046                               0.103286
# 29                              0.1256                               0.103857
# 32                              0.1870                               0.113000
#
#     AveragePrice_NaturalGas_Household  AveragePrice_NaturalGas_NonHousehold  \
# 20                           0.855667                                0.4852
# 23                           0.869667                                0.4688
# 26                           0.878000                                0.4598
# 29                           0.914667                                0.4866
# 32                           1.038667                                0.4982
#
#     Half_Year
# 20       2015
# 23       2016
# 26       2017
# 29       2018
# 32       2019
#
# [5 rows x 28 columns]

# %%
# Group by 'Year' and take the mean GDP
gdp_yearly = gdp.groupby("Year", as_index=False)["GDP"].mean()

# Display the first few rows
gdp_yearly.head()
# Out:
#    Year         GDP
# 0  2015  174803.350
# 1  2016  180082.350
# 2  2017  187778.575
# 3  2018  196865.025
# 4  2019  207444.700

# %%
# Merge GDP and Energy Price Data
merged_Yearly_data = pd.merge(populationNL, rEnergy, on=["Year"], how="inner")
merged_Yearly_data = pd.merge(merged_Yearly_data, residential_pivot, on=["Year"], how="inner")
merged_Yearly_data = pd.merge(merged_Yearly_data, yearly_load, on=["Year"], how="inner")
merged_Yearly_data = pd.merge(merged_Yearly_data, YearlyFinalCons, on=["Year"], how="inner")
merged_Yearly_data = pd.merge(merged_Yearly_data, gdp_yearly, on=["Year"], how="inner")
merged_Yearly_data = pd.merge(merged_Yearly_data, energyPrice_yearly, on=["Year"], how="inner")

# %%
merged_Yearly_data
# Out:
#     Year Population  GeothermalHeat (MWh)  AmbientAirHeat (MWh)  \
# 0   2015      16,90            1009452.52             560837.82
# 1   2015      16,90            1009452.52             560837.82
# 2   2015      16,90            1009452.52             560837.82
# 3   2016      16,98            1070841.90             731950.30
# 4   2016      16,98            1070841.90             731950.30
# 5   2016      16,98            1070841.90             731950.30
# 6   2017      17,08            1133620.18             980285.62
# 7   2017      17,08            1133620.18             980285.62
# 8   2017      17,08            1133620.18             980285.62
# 9   2018      17,18            1217509.74            1296677.04
# 10  2018      17,18            1217509.74            1296677.04
# 11  2018      17,18            1217509.74            1296677.04
# 12  2019      17,28            1309732.70            1713069.26
# 13  2019      17,28            1309732.70            1713069.26
# 14  2019      17,28            1309732.70            1713069.26
# 15  2020      17,41            1415844.66            2225573.36
# 16  2020      17,41            1415844.66            2225573.36
# 17  2020      17,41            1415844.66            2225573.36
# 18  2021      17,48            1533345.60            2918634.46
# 19  2021      17,48            1533345.60            2918634.46
# 20  2021      17,48            1533345.60            2918634.46
# 21  2022      17,59            1662235.52            3941975.98
# 22  2022      17,59            1662235.52            3941975.98
# 23  2022      17,59            1662235.52            3941975.98
#
#     TotalGeothermal&GroundEnergy (MWh)  TotalBiomass (MWh)  \
# 0                           1689457.96         21863230.46
# 1                           1689457.96         21863230.46
# 2                           1689457.96         21863230.46
# 3                           1860848.22         20963778.82
# 4                           1860848.22         20963778.82
# 5                           1860848.22         20963778.82
# 6                           1979738.06         22786015.62
# 7                           1979738.06         22786015.62
# 8                           1979738.06         22786015.62
# 9                           2253906.92         25712983.48
# 10                          2253906.92         25712983.48
# 11                          2253906.92         25712983.48
# 12                          2855300.62         30123852.10
# 13                          2855300.62         30123852.10
# 14                          2855300.62         30123852.10
# 15                          3133913.96         33456934.32
# 16                          3133913.96         33456934.32
# 17                          3133913.96         33456934.32
# 18                          3290859.66         35205837.20
# 19                          3290859.66         35205837.20
# 20                          3290859.66         35205837.20
# 21                          3550861.74         30623578.32
# 22                          3550861.74         30623578.32
# 23                          3550861.74         30623578.32
#
#     TotalRes(excl.Stat.Transfer) (MWh)  TotalRes(incl.Stat.Transfer) (MWh)  \
# 0                          32553593.76                         32553593.76
# 1                          32553593.76                         32553593.76
# 2                          32553593.76                         32553593.76
# 3                          33938327.06                         33938327.06
# 4                          33938327.06                         33938327.06
# 5                          33938327.06                         33938327.06
# 6                          38004470.70                         38004470.70
# 7                          38004470.70                         38004470.70
# 8                          38004470.70                         38004470.70
# 9                          43418125.12                         43418125.12
# 10                         43418125.12                         43418125.12
# 11                         43418125.12                         43418125.12
# 12                         51287076.96                         51287076.96
# 13                         51287076.96                         51287076.96
# 14                         51287076.96                         51287076.96
# 15                         61949106.70                         75599215.90
# 16                         61949106.70                         75599215.90
# 17                         61949106.70                         75599215.90
# 18                         72131410.38                         72131410.38
# 19                         72131410.38                         72131410.38
# 20                         72131410.38                         72131410.38
# 21                         76588390.48                         76588390.48
# 22                         76588390.48                         76588390.48
# 23                         76588390.48                         76588390.48
#
#     Totaal windenergie (MWh)  TotalSolarEnergy (MWh)  ...  \
# 0                 6916722.00              1424178.06  ...
# 1                 6916722.00              1424178.06  ...
# 2                 6916722.00              1424178.06  ...
# 3                 8363955.80              1920293.14  ...
# 4                 8363955.80              1920293.14  ...
# 5                 8363955.80              1920293.14  ...
# 6                 9641743.80              2522242.40  ...
# 7                 9641743.80              2522242.40  ...
# 8                 9641743.80              2522242.40  ...
# 9                10029524.68              4030587.80  ...
# 10               10029524.68              4030587.80  ...
# 11               10029524.68              4030587.80  ...
# 12               10773419.52              5726990.26  ...
# 13               10773419.52              5726990.26  ...
# 14               10773419.52              5726990.26  ...
# 15               13948722.70              9091461.62  ...
# 16               13948722.70              9091461.62  ...
# 17               13948722.70              9091461.62  ...
# 18               18998485.32             11627315.24  ...
# 19               18998485.32             11627315.24  ...
# 20               18998485.32             11627315.24  ...
# 21               21404060.12             16981246.96  ...
# 22               21404060.12             16981246.96  ...
# 23               21404060.12             16981246.96  ...
#
#     Electricity_NonHousehold_500to2000MWh_EuroPerKWh  \
# 0                                              0.106
# 1                                              0.082
# 2                                              0.024
# 3                                              0.102
# 4                                              0.079
# 5                                              0.023
# 6                                              0.095
# 7                                              0.073
# 8                                              0.022
# 9                                              0.101
# 10                                             0.079
# 11                                             0.022
# 12                                             0.111
# 13                                             0.088
# 14                                             0.023
# 15                                             0.126
# 16                                             0.103
# 17                                             0.023
# 18                                             0.143
# 19                                             0.117
# 20                                             0.026
# 21                                             0.201
# 22                                             0.175
# 23                                             0.027
#
#     Electricity_NonHousehold_2000to20000MWh_EuroPerKWh  \
# 0                                               0.098
# 1                                               0.077
# 2                                               0.021
# 3                                               0.093
# 4                                               0.072
# 5                                               0.021
# 6                                               0.093
# 7                                               0.069
# 8                                               0.024
# 9                                               0.095
# 10                                              0.074
# 11                                              0.021
# 12                                              0.104
# 13                                              0.084
# 14                                              0.020
# 15                                              0.119
# 16                                              0.099
# 17                                              0.020
# 18                                              0.141
# 19                                              0.119
# 20                                              0.022
# 21                                              0.219
# 22                                              0.196
# 23                                              0.024
#
#     Electricity_NonHousehold_20000to70000MWh_EuroPerKWh  \
# 0                                               0.081
# 1                                               0.062
# 2                                               0.019
# 3                                               0.075
# 4                                               0.056
# 5                                               0.019
# 6                                               0.069
# 7                                               0.053
# 8                                               0.016
# 9                                               0.073
# 10                                              0.058
# 11                                              0.015
# 12                                              0.078
# 13                                              0.063
# 14                                              0.015
# 15                                              0.084
# 16                                              0.069
# 17                                              0.015
# 18                                              0.102
# 19                                              0.084
# 20                                              0.018
# 21                                              0.183
# 22                                              0.163
# 23                                              0.020
#
#     Electricity_NonHousehold_70000to150000MWh_EuroPerKWh  \
# 0                                               0.084
# 1                                               0.060
# 2                                               0.024
# 3                                               0.072
# 4                                               0.054
# 5                                               0.018
# 6                                               0.064
# 7                                               0.049
# 8                                               0.015
# 9                                               0.070
# 10                                              0.055
# 11                                              0.015
# 12                                              0.072
# 13                                              0.060
# 14                                              0.012
# 15                                              0.078
# 16                                              0.064
# 17                                              0.013
# 18                                              0.088
# 19                                              0.069
# 20                                              0.019
# 21                                              0.171
# 22                                              0.153
# 23                                              0.018
#
#     Electricity_NonHousehold_MoreThan_150000MWh_EuroPerKWh  \
# 0                                               0.079
# 1                                               0.057
# 2                                               0.022
# 3                                               0.070
# 4                                               0.050
# 5                                               0.020
# 6                                               0.065
# 7                                               0.048
# 8                                               0.017
# 9                                               0.067
# 10                                              0.052
# 11                                              0.015
# 12                                              0.072
# 13                                              0.057
# 14                                              0.015
# 15                                              0.072
# 16                                              0.059
# 17                                              0.014
# 18                                              0.105
# 19                                              0.085
# 20                                              0.020
# 21                                              0.189
# 22                                              0.168
# 23                                              0.020
#
#     AveragePrice_Electricity_Household  AveragePrice_Electricity_NonHousehold  \
# 0                               0.1400                               0.116571
# 1                               0.0226                               0.086857
# 2                               0.1174                               0.029714
# 3                               0.1122                               0.105857
# 4                              -0.0044                               0.077571
# 5                               0.1166                               0.028286
# 6                               0.1046                               0.103286
# 7                              -0.0078                               0.076143
# 8                               0.1124                               0.027143
# 9                               0.1256                               0.103857
# 10                              0.0078                               0.076571
# 11                              0.1178                               0.027286
# 12                              0.1870                               0.113000
# 13                              0.0696                               0.086143
# 14                              0.1176                               0.026857
# 15                              0.0768                               0.124000
# 16                             -0.0450                               0.096286
# 17                              0.1220                               0.027714
# 18                              0.0696                               0.143143
# 19                             -0.0576                               0.109714
# 20                              0.1270                               0.033429
# 21                             -0.0060                               0.210857
# 22                             -0.1260                               0.176143
# 23                              0.1200                               0.034857
#
#     AveragePrice_NaturalGas_Household  AveragePrice_NaturalGas_NonHousehold  \
# 0                            0.855667                                0.4852
# 1                            0.703333                                0.4552
# 2                            0.152333                                0.0300
# 3                            0.869667                                0.4688
# 4                            0.726000                                0.4384
# 5                            0.143667                                0.0304
# 6                            0.878000                                0.4598
# 7                            0.706667                                0.4254
# 8                            0.171333                                0.0344
# 9                            0.914667                                0.4866
# 10                           0.751333                                0.4514
# 11                           0.163333                                0.0352
# 12                           1.038667                                0.4982
# 13                           0.865667                                0.4664
# 14                           0.172667                                0.0322
# 15                           1.104333                                0.5206
# 16                           0.918000                                0.4834
# 17                           0.186667                                0.0372
# 18                           1.105333                                0.6262
# 19                           0.924667                                0.5884
# 20                           0.180667                                0.0380
# 21                           1.590667                                1.0328
# 22                           1.403000                                0.9916
# 23                           0.187333                                0.0410
#
#     Half_Year
# 0        2015
# 1        2015
# 2        2015
# 3        2016
# 4        2016
# 5        2016
# 6        2017
# 7        2017
# 8        2017
# 9        2018
# 10       2018
# 11       2018
# 12       2019
# 13       2019
# 14       2019
# 15       2020
# 16       2020
# 17       2020
# 18       2021
# 19       2021
# 20       2021
# 21       2022
# 22       2022
# 23       2022
#
# [24 rows x 78 columns]

# %%
merged_Yearly_data.to_csv('merged_Yearly_data,csv', index = False )

# %% [markdown]
# ## Multi-Stage Prediction

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split

# Define features (drop non-relevant columns)
X_long = merged_Yearly_data.drop(columns=["Year", "loadConsumption"], errors="ignore")
y_long = merged_Yearly_data["loadConsumption"]

# Convert any non-numeric columns
X_long = X_long.apply(pd.to_numeric, errors="coerce")

# Handle missing values
X_long.fillna(X_long.median(), inplace=True)

# Train-test split
X_train_long, X_test_long, y_train_long, y_test_long = train_test_split(
    X_long, y_long, test_size=0.2, random_state=42
)

# Train the model
model_long_term = XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=42)

model_long_term.fit(X_train_long, y_train_long)

# Predict yearly load consumption
yearly_predictions = model_long_term.predict(X_long)
merged_Yearly_data["Predicted_Load"] = yearly_predictions

# %%
merged_Yearly_data
# Out:
#     Year Population  GeothermalHeat (MWh)  AmbientAirHeat (MWh)  \
# 0   2015      16,90            1009452.52             560837.82
# 1   2015      16,90            1009452.52             560837.82
# 2   2015      16,90            1009452.52             560837.82
# 3   2016      16,98            1070841.90             731950.30
# 4   2016      16,98            1070841.90             731950.30
# 5   2016      16,98            1070841.90             731950.30
# 6   2017      17,08            1133620.18             980285.62
# 7   2017      17,08            1133620.18             980285.62
# 8   2017      17,08            1133620.18             980285.62
# 9   2018      17,18            1217509.74            1296677.04
# 10  2018      17,18            1217509.74            1296677.04
# 11  2018      17,18            1217509.74            1296677.04
# 12  2019      17,28            1309732.70            1713069.26
# 13  2019      17,28            1309732.70            1713069.26
# 14  2019      17,28            1309732.70            1713069.26
# 15  2020      17,41            1415844.66            2225573.36
# 16  2020      17,41            1415844.66            2225573.36
# 17  2020      17,41            1415844.66            2225573.36
# 18  2021      17,48            1533345.60            2918634.46
# 19  2021      17,48            1533345.60            2918634.46
# 20  2021      17,48            1533345.60            2918634.46
# 21  2022      17,59            1662235.52            3941975.98
# 22  2022      17,59            1662235.52            3941975.98
# 23  2022      17,59            1662235.52            3941975.98
#
#     TotalGeothermal&GroundEnergy (MWh)  TotalBiomass (MWh)  \
# 0                           1689457.96         21863230.46
# 1                           1689457.96         21863230.46
# 2                           1689457.96         21863230.46
# 3                           1860848.22         20963778.82
# 4                           1860848.22         20963778.82
# 5                           1860848.22         20963778.82
# 6                           1979738.06         22786015.62
# 7                           1979738.06         22786015.62
# 8                           1979738.06         22786015.62
# 9                           2253906.92         25712983.48
# 10                          2253906.92         25712983.48
# 11                          2253906.92         25712983.48
# 12                          2855300.62         30123852.10
# 13                          2855300.62         30123852.10
# 14                          2855300.62         30123852.10
# 15                          3133913.96         33456934.32
# 16                          3133913.96         33456934.32
# 17                          3133913.96         33456934.32
# 18                          3290859.66         35205837.20
# 19                          3290859.66         35205837.20
# 20                          3290859.66         35205837.20
# 21                          3550861.74         30623578.32
# 22                          3550861.74         30623578.32
# 23                          3550861.74         30623578.32
#
#     TotalRes(excl.Stat.Transfer) (MWh)  TotalRes(incl.Stat.Transfer) (MWh)  \
# 0                          32553593.76                         32553593.76
# 1                          32553593.76                         32553593.76
# 2                          32553593.76                         32553593.76
# 3                          33938327.06                         33938327.06
# 4                          33938327.06                         33938327.06
# 5                          33938327.06                         33938327.06
# 6                          38004470.70                         38004470.70
# 7                          38004470.70                         38004470.70
# 8                          38004470.70                         38004470.70
# 9                          43418125.12                         43418125.12
# 10                         43418125.12                         43418125.12
# 11                         43418125.12                         43418125.12
# 12                         51287076.96                         51287076.96
# 13                         51287076.96                         51287076.96
# 14                         51287076.96                         51287076.96
# 15                         61949106.70                         75599215.90
# 16                         61949106.70                         75599215.90
# 17                         61949106.70                         75599215.90
# 18                         72131410.38                         72131410.38
# 19                         72131410.38                         72131410.38
# 20                         72131410.38                         72131410.38
# 21                         76588390.48                         76588390.48
# 22                         76588390.48                         76588390.48
# 23                         76588390.48                         76588390.48
#
#     Totaal windenergie (MWh)  TotalSolarEnergy (MWh)  ...  \
# 0                 6916722.00              1424178.06  ...
# 1                 6916722.00              1424178.06  ...
# 2                 6916722.00              1424178.06  ...
# 3                 8363955.80              1920293.14  ...
# 4                 8363955.80              1920293.14  ...
# 5                 8363955.80              1920293.14  ...
# 6                 9641743.80              2522242.40  ...
# 7                 9641743.80              2522242.40  ...
# 8                 9641743.80              2522242.40  ...
# 9                10029524.68              4030587.80  ...
# 10               10029524.68              4030587.80  ...
# 11               10029524.68              4030587.80  ...
# 12               10773419.52              5726990.26  ...
# 13               10773419.52              5726990.26  ...
# 14               10773419.52              5726990.26  ...
# 15               13948722.70              9091461.62  ...
# 16               13948722.70              9091461.62  ...
# 17               13948722.70              9091461.62  ...
# 18               18998485.32             11627315.24  ...
# 19               18998485.32             11627315.24  ...
# 20               18998485.32             11627315.24  ...
# 21               21404060.12             16981246.96  ...
# 22               21404060.12             16981246.96  ...
# 23               21404060.12             16981246.96  ...
#
#     Electricity_NonHousehold_2000to20000MWh_EuroPerKWh  \
# 0                                               0.098
# 1                                               0.077
# 2                                               0.021
# 3                                               0.093
# 4                                               0.072
# 5                                               0.021
# 6                                               0.093
# 7                                               0.069
# 8                                               0.024
# 9                                               0.095
# 10                                              0.074
# 11                                              0.021
# 12                                              0.104
# 13                                              0.084
# 14                                              0.020
# 15                                              0.119
# 16                                              0.099
# 17                                              0.020
# 18                                              0.141
# 19                                              0.119
# 20                                              0.022
# 21                                              0.219
# 22                                              0.196
# 23                                              0.024
#
#     Electricity_NonHousehold_20000to70000MWh_EuroPerKWh  \
# 0                                               0.081
# 1                                               0.062
# 2                                               0.019
# 3                                               0.075
# 4                                               0.056
# 5                                               0.019
# 6                                               0.069
# 7                                               0.053
# 8                                               0.016
# 9                                               0.073
# 10                                              0.058
# 11                                              0.015
# 12                                              0.078
# 13                                              0.063
# 14                                              0.015
# 15                                              0.084
# 16                                              0.069
# 17                                              0.015
# 18                                              0.102
# 19                                              0.084
# 20                                              0.018
# 21                                              0.183
# 22                                              0.163
# 23                                              0.020
#
#     Electricity_NonHousehold_70000to150000MWh_EuroPerKWh  \
# 0                                               0.084
# 1                                               0.060
# 2                                               0.024
# 3                                               0.072
# 4                                               0.054
# 5                                               0.018
# 6                                               0.064
# 7                                               0.049
# 8                                               0.015
# 9                                               0.070
# 10                                              0.055
# 11                                              0.015
# 12                                              0.072
# 13                                              0.060
# 14                                              0.012
# 15                                              0.078
# 16                                              0.064
# 17                                              0.013
# 18                                              0.088
# 19                                              0.069
# 20                                              0.019
# 21                                              0.171
# 22                                              0.153
# 23                                              0.018
#
#     Electricity_NonHousehold_MoreThan_150000MWh_EuroPerKWh  \
# 0                                               0.079
# 1                                               0.057
# 2                                               0.022
# 3                                               0.070
# 4                                               0.050
# 5                                               0.020
# 6                                               0.065
# 7                                               0.048
# 8                                               0.017
# 9                                               0.067
# 10                                              0.052
# 11                                              0.015
# 12                                              0.072
# 13                                              0.057
# 14                                              0.015
# 15                                              0.072
# 16                                              0.059
# 17                                              0.014
# 18                                              0.105
# 19                                              0.085
# 20                                              0.020
# 21                                              0.189
# 22                                              0.168
# 23                                              0.020
#
#     AveragePrice_Electricity_Household  AveragePrice_Electricity_NonHousehold  \
# 0                               0.1400                               0.116571
# 1                               0.0226                               0.086857
# 2                               0.1174                               0.029714
# 3                               0.1122                               0.105857
# 4                              -0.0044                               0.077571
# 5                               0.1166                               0.028286
# 6                               0.1046                               0.103286
# 7                              -0.0078                               0.076143
# 8                               0.1124                               0.027143
# 9                               0.1256                               0.103857
# 10                              0.0078                               0.076571
# 11                              0.1178                               0.027286
# 12                              0.1870                               0.113000
# 13                              0.0696                               0.086143
# 14                              0.1176                               0.026857
# 15                              0.0768                               0.124000
# 16                             -0.0450                               0.096286
# 17                              0.1220                               0.027714
# 18                              0.0696                               0.143143
# 19                             -0.0576                               0.109714
# 20                              0.1270                               0.033429
# 21                             -0.0060                               0.210857
# 22                             -0.1260                               0.176143
# 23                              0.1200                               0.034857
#
#     AveragePrice_NaturalGas_Household  AveragePrice_NaturalGas_NonHousehold  \
# 0                            0.855667                                0.4852
# 1                            0.703333                                0.4552
# 2                            0.152333                                0.0300
# 3                            0.869667                                0.4688
# 4                            0.726000                                0.4384
# 5                            0.143667                                0.0304
# 6                            0.878000                                0.4598
# 7                            0.706667                                0.4254
# 8                            0.171333                                0.0344
# 9                            0.914667                                0.4866
# 10                           0.751333                                0.4514
# 11                           0.163333                                0.0352
# 12                           1.038667                                0.4982
# 13                           0.865667                                0.4664
# 14                           0.172667                                0.0322
# 15                           1.104333                                0.5206
# 16                           0.918000                                0.4834
# 17                           0.186667                                0.0372
# 18                           1.105333                                0.6262
# 19                           0.924667                                0.5884
# 20                           0.180667                                0.0380
# 21                           1.590667                                1.0328
# 22                           1.403000                                0.9916
# 23                           0.187333                                0.0410
#
#     Half_Year  Predicted_Load
# 0        2015     113238456.0
# 1        2015     113238456.0
# 2        2015     113238456.0
# 3        2016     114529616.0
# 4        2016     114529616.0
# 5        2016     114529616.0
# 6        2017     115017912.0
# 7        2017     115017912.0
# 8        2017     115017912.0
# 9        2018     116517008.0
# 10       2018     116517008.0
# 11       2018     116517008.0
# 12       2019     113923880.0
# 13       2019     113923880.0
# 14       2019     113923880.0
# 15       2020     108138232.0
# 16       2020     108138232.0
# 17       2020     108138232.0
# 18       2021     106378776.0
# 19       2021     106378776.0
# 20       2021     106378776.0
# 21       2022     100381872.0
# 22       2022     100381872.0
# 23       2022     100381872.0
#
# [24 rows x 79 columns]

# %%
# Merge yearly predictions with monthly data
monthlyData = merged_monthly_data.merge(merged_Yearly_data[["Year", "Predicted_Load"]], on="Year", how="left")

# Normalize historical monthly distribution
monthly_total = monthlyData.groupby("Year")["loadConsumption"].transform("sum")
monthlyData["Long_Term_Trend"] = (monthlyData["loadConsumption"] / monthly_total) * monthlyData["Predicted_Load"]

# Save updated dataset
#monthly_data.to_csv("/mnt/data/monthly_with_long_term_trend.csv", index=False)

monthlyData
# Out:
#      Year  Month  Gross production (MWh)  \
# 0    2015      1                10700000
# 1    2015      1                10700000
# 2    2015      1                10700000
# 3    2015      2                 9695000
# 4    2015      2                 9695000
# ..    ...    ...                     ...
# 283  2022     11                 9290000
# 284  2022     11                 9290000
# 285  2022     12                11072000
# 286  2022     12                11072000
# 287  2022     12                11072000
#
#      Net production/Net production, total (MWh)  \
# 0                                      10301000
# 1                                      10301000
# 2                                      10301000
# 3                                       9328000
# 4                                       9328000
# ..                                          ...
# 283                                     8987000
# 284                                     8987000
# 285                                    10725000
# 286                                    10725000
# 287                                    10725000
#
#      Net production/Nuclear energy (MWh)  \
# 0                               364000.0
# 1                               364000.0
# 2                               364000.0
# 3                               329000.0
# 4                               329000.0
# ..                                   ...
# 283                             346000.0
# 284                             346000.0
# 285                             361000.0
# 286                             361000.0
# 287                             361000.0
#
#      Net production/Fuels/Fuels, total (MWh)  Net production/Fuels/Coal (MWh)  \
# 0                                    8918000                          3771000
# 1                                    8918000                          3771000
# 2                                    8918000                          3771000
# 3                                    8310000                          3348000
# 4                                    8310000                          3348000
# ..                                       ...                              ...
# 283                                  5415000                          1236000
# 284                                  5415000                          1236000
# 285                                  7789000                          1700000
# 286                                  7789000                          1700000
# 287                                  7789000                          1700000
#
#      Net production/Fuels/Petroleum products (MWh)  \
# 0                                            96000
# 1                                            96000
# 2                                            96000
# 3                                            79000
# 4                                            79000
# ..                                             ...
# 283                                         106000
# 284                                         106000
# 285                                         144000
# 286                                         144000
# 287                                         144000
#
#      Net production/Fuels/Natural gas (MWh)  \
# 0                                   4605000
# 1                                   4605000
# 2                                   4605000
# 3                                   4464000
# 4                                   4464000
# ..                                      ...
# 283                                 3199000
# 284                                 3199000
# 285                                 5079000
# 286                                 5079000
# 287                                 5079000
#
#      Net production/Fuels/Biomass (MWh)  ...  \
# 0                                349000  ...
# 1                                349000  ...
# 2                                349000  ...
# 3                                328000  ...
# 4                                328000  ...
# ..                                  ...  ...
# 283                              755000  ...
# 284                              755000  ...
# 285                              745000  ...
# 286                              745000  ...
# 287                              745000  ...
#
#      Net production/Wind energy/Wind energy off shore (MWh)  \
# 0                                                98000
# 1                                                98000
# 2                                                98000
# 3                                                65000
# 4                                                65000
# ..                                                 ...
# 283                                             991000
# 284                                             991000
# 285                                             896000
# 286                                             896000
# 287                                             896000
#
#      Net production/Solar photovoltaic (MWh)  \
# 0                                      28000
# 1                                      28000
# 2                                      28000
# 3                                      58000
# 4                                      58000
# ..                                       ...
# 283                                   478000
# 284                                   478000
# 285                                   250000
# 286                                   250000
# 287                                   250000
#
#      Net production/Other sources (MWh)  Imports/Imports, total (MWh)  \
# 0                                111000                       2432000
# 1                                111000                       2432000
# 2                                111000                       2432000
# 3                                116000                       2371000
# 4                                116000                       2371000
# ..                                  ...                           ...
# 283                               47000                       2150000
# 284                               47000                       2150000
# 285                               46000                       1513000
# 286                               46000                       1513000
# 287                               46000                       1513000
#
#      Exports/Exports, total (MWh)  Net consumption (calculated) (MWh)   NAO  \
# 0                         1979000                            10263000  1.79
# 1                         1979000                            10263000  1.79
# 2                         1979000                            10263000  1.79
# 3                         2110000                             9150000  1.32
# 4                         2110000                             9150000  1.32
# ..                            ...                                 ...   ...
# 283                       1868000                             8841000  0.69
# 284                       1868000                             8841000  0.69
# 285                       2145000                             9646000 -0.15
# 286                       2145000                             9646000 -0.15
# 287                       2145000                             9646000 -0.15
#
#      loadConsumption  Predicted_Load  Long_Term_Trend
# 0       1.046155e+07     113238456.0     3.487177e+06
# 1       1.046155e+07     113238456.0     3.487177e+06
# 2       1.046155e+07     113238456.0     3.487177e+06
# 3       9.287981e+06     113238456.0     3.095989e+06
# 4       9.287981e+06     113238456.0     3.095989e+06
# ..               ...             ...              ...
# 283     8.812078e+06     100381872.0     2.937501e+06
# 284     8.812078e+06     100381872.0     2.937501e+06
# 285     9.676477e+06     100381872.0     3.225648e+06
# 286     9.676477e+06     100381872.0     3.225648e+06
# 287     9.676477e+06     100381872.0     3.225648e+06
#
# [288 rows x 24 columns]

# %%
merged_data
# Out:
#        datetime  loadConsumption  DailyPrecipitation  MaxHourlyPrecipitation  \
# 0    2015-01-01      286667.0000                -0.1                    -0.1
# 1    2015-01-02      319584.0000                 4.3                     1.7
# 2    2015-01-03      312955.0000                 1.5                     0.5
# 3    2015-01-04      296676.0000                -0.1                    -0.1
# 4    2015-01-05      351510.0000                 0.0                     0.0
# ...         ...              ...                 ...                     ...
# 3282 2023-12-27      305610.2900                 3.4                     1.3
# 3283 2023-12-28      326312.3400                 0.8                     0.6
# 3284 2023-12-29      314575.3300                 3.8                     1.4
# 3285 2023-12-30      290563.1625                -0.1                    -0.1
# 3286 2023-12-31      296833.7350                 2.8                     1.6
#
#       HDMaxPrecipitation  DailyMeanTemperature  HourlyMinTemperature  \
# 0                      1                   3.0                    10
# 1                      3                   7.3                    44
# 2                     10                   3.8                    26
# 3                      1                   3.9                    -3
# 4                      1                   2.4                     9
# ...                  ...                   ...                   ...
# 3282                   8                   7.0                     6
# 3283                  23                  10.9                   100
# 3284                  16                   9.3                    55
# 3285                   1                   8.1                    55
# 3286                  10                   8.8                    79
#
#       HDMinTemperature  HourlyMaxTemperature  HDMaxTemperature  \
# 0                    5                   4.7                24
# 1                    1                  10.1                 8
# 2                   17                   5.9                 1
# 3                   21                   8.0                13
# 4                   11                   3.8                24
# ...                ...                   ...               ...
# 3282                 2                  10.7                24
# 3283                24                  11.5                13
# 3284                18                  11.4                13
# 3285                 7                   9.7                18
# 3286                22                   9.5                17
#
#       DailyMeanWindspeed  MaxHourlyMeanWindspeed  HDMaxMeanWindspeed  \
# 0                    5.4                     8.0                  24
# 1                    6.1                     9.0                   2
# 2                    3.3                     5.0                   7
# 3                    2.4                     3.0                  11
# 4                    3.0                     5.0                  11
# ...                  ...                     ...                 ...
# 3282                 4.5                     7.0                  19
# 3283                 8.1                     9.0                   7
# 3284                 6.0                     9.0                   1
# 3285                 4.2                     5.0                  13
# 3286                 6.4                     8.0                  12
#
#       MinHourlyMeanWindspeed  HDMinMeanWindspeed  Month  Year  Week  WeekKey  \
# 0                        4.0                   1      1  2015     1   201501
# 1                        4.0                  20      1  2015     1   201501
# 2                        1.0                  17      1  2015     1   201501
# 3                        2.0                   1      1  2015     1   201501
# 4                        1.0                  22      1  2015     2   201502
# ...                      ...                 ...    ...   ...   ...      ...
# 3282                     1.0                   1     12  2023    52   202352
# 3283                     6.0                   1     12  2023    52   202352
# 3284                     2.0                  18     12  2023    52   202352
# 3285                     3.0                   6     12  2023    52   202352
# 3286                     4.0                   1     12  2023    52   202352
#
#      day_of_week
# 0       Thursday
# 1         Friday
# 2       Saturday
# 3         Sunday
# 4         Monday
# ...          ...
# 3282   Wednesday
# 3283    Thursday
# 3284      Friday
# 3285    Saturday
# 3286      Sunday
#
# [3287 rows x 20 columns]

# %%
# Extract Year and Month in Daily Data
merged_data["datetime"] = pd.to_datetime(merged_data["datetime"])
merged_data["Year"] = merged_data["datetime"].dt.year
merged_data["Month"] = merged_data["datetime"].dt.month

# Merge monthly predictions with daily data
merged_data = merged_data.merge(monthlyData[["Year", "Month", "Long_Term_Trend"]], on=["Year", "Month"], how="left")

# Normalize based on past daily distribution
daily_total = merged_data.groupby(["Year", "Month"])["loadConsumption"].transform("sum")
merged_data["Long_Term_Trend"] = (merged_data["loadConsumption"] / daily_total) * merged_data["Long_Term_Trend"]

# %%
from prophet import Prophet

# Compute short-term residuals
merged_data["Short_Term_Residual"] = merged_data["loadConsumption"] - merged_data["Long_Term_Trend"]

# Prepare data for Prophet
prophet_data = merged_data[["datetime", "Short_Term_Residual"]].rename(columns={"datetime": "ds", "Short_Term_Residual": "y"})

# Train Prophet model
prophet = Prophet()
prophet.fit(prophet_data)

# Predict short-term variations
future_dates = prophet.make_future_dataframe(periods=180)
short_term_preds = prophet.predict(future_dates)

# Save predictions
merged_data["Final_Prediction"] = merged_data["Long_Term_Trend"] + short_term_preds["yhat"]
# Out:
# Importing plotly failed. Interactive plots will not work.
# 22:24:42 - cmdstanpy - INFO - Chain [1] start processing
# 22:24:46 - cmdstanpy - INFO - Chain [1] done processing

# %%
merged_data = merged_data[merged_data["Year"] <= 2022]

# %%
merged_data
# Out:
#        datetime  loadConsumption  DailyPrecipitation  MaxHourlyPrecipitation  \
# 0    2015-01-01      286667.0000                -0.1                    -0.1
# 1    2015-01-01      286667.0000                -0.1                    -0.1
# 2    2015-01-01      286667.0000                -0.1                    -0.1
# 3    2015-01-02      319584.0000                 4.3                     1.7
# 4    2015-01-02      319584.0000                 4.3                     1.7
# ...         ...              ...                 ...                     ...
# 8761 2022-12-30      297210.1750                 5.2                     2.2
# 8762 2022-12-30      297210.1750                 5.2                     2.2
# 8763 2022-12-31      274811.7625                21.2                     3.6
# 8764 2022-12-31      274811.7625                21.2                     3.6
# 8765 2022-12-31      274811.7625                21.2                     3.6
#
#       HDMaxPrecipitation  DailyMeanTemperature  HourlyMinTemperature  \
# 0                      1                   3.0                    10
# 1                      1                   3.0                    10
# 2                      1                   3.0                    10
# 3                      3                   7.3                    44
# 4                      3                   7.3                    44
# ...                  ...                   ...                   ...
# 8761                  24                   8.5                    46
# 8762                  24                   8.5                    46
# 8763                   5                  14.0                   104
# 8764                   5                  14.0                   104
# 8765                   5                  14.0                   104
#
#       HDMinTemperature  HourlyMaxTemperature  HDMaxTemperature  ...  \
# 0                    5                   4.7                24  ...
# 1                    5                   4.7                24  ...
# 2                    5                   4.7                24  ...
# 3                    1                  10.1                 8  ...
# 4                    1                  10.1                 8  ...
# ...                ...                   ...               ...  ...
# 8761                 7                  12.9                22  ...
# 8762                 7                  12.9                22  ...
# 8763                 5                  15.9                19  ...
# 8764                 5                  15.9                19  ...
# 8765                 5                  15.9                19  ...
#
#       MinHourlyMeanWindspeed  HDMinMeanWindspeed  Month  Year  Week  WeekKey  \
# 0                        4.0                   1      1  2015     1   201501
# 1                        4.0                   1      1  2015     1   201501
# 2                        4.0                   1      1  2015     1   201501
# 3                        4.0                  20      1  2015     1   201501
# 4                        4.0                  20      1  2015     1   201501
# ...                      ...                 ...    ...   ...   ...      ...
# 8761                     4.0                   3     12  2022    52   202252
# 8762                     4.0                   3     12  2022    52   202252
# 8763                     3.0                   5     12  2022    52   202252
# 8764                     3.0                   5     12  2022    52   202252
# 8765                     3.0                   5     12  2022    52   202252
#
#       day_of_week  Long_Term_Trend  Short_Term_Residual Final_Prediction
# 0        Thursday     31851.841634        254815.158366    331250.291941
# 1        Thursday     31851.841634        254815.158366    328845.048421
# 2        Thursday     31851.841634        254815.158366    301917.795804
# 3          Friday     35509.280652        284074.719348    295422.837293
# 4          Friday     35509.280652        284074.719348    333159.541357
# ...           ...              ...                  ...              ...
# 8761       Friday     33024.943786        264185.231214              NaN
# 8762       Friday     33024.943786        264185.231214              NaN
# 8763     Saturday     30536.111384        244275.651116              NaN
# 8764     Saturday     30536.111384        244275.651116              NaN
# 8765     Saturday     30536.111384        244275.651116              NaN
#
# [8766 rows x 23 columns]

# %%
merged_data.isna().sum()
# Out:
# datetime                     0
# loadConsumption              0
# DailyPrecipitation           0
# MaxHourlyPrecipitation       0
# HDMaxPrecipitation           0
# DailyMeanTemperature         0
# HourlyMinTemperature         0
# HDMinTemperature             0
# HourlyMaxTemperature         0
# HDMaxTemperature             0
# DailyMeanWindspeed           0
# MaxHourlyMeanWindspeed       0
# HDMaxMeanWindspeed           0
# MinHourlyMeanWindspeed       0
# HDMinMeanWindspeed           0
# Month                        0
# Year                         0
# Week                         0
# WeekKey                      0
# day_of_week                  0
# Long_Term_Trend              0
# Short_Term_Residual          0
# Final_Prediction          5299
# dtype: int64

# %%
merged_data.to_csv("daily_final_predictions_Prophet.csv", index=False)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Define actual and predicted values
y_true = merged_data["loadConsumption"]
y_pred = merged_data["Final_Prediction"]

# Compute evaluation metrics
mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_true, y_pred)

# Display metrics
metrics = pd.DataFrame({
    "Metric": ["Mean Absolute Error (MAE)", "Mean Squared Error (MSE)", "Root Mean Squared Error (RMSE)", "R² Score"],
    "Value": [mae, mse, rmse, r2]
})

metrics
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 8
#       5 y_pred = merged_data["Final_Prediction"]
#       7 # Compute evaluation metrics
# ----> 8 mae = mean_absolute_error(y_true, y_pred)
#       9 mse = mean_squared_error(y_true, y_pred)
#      10 rmse = np.sqrt(mse)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:204, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     140 @validate_params(
#     141     {
#     142         "y_true": ["array-like"],
#    (...)
#     150     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     151 ):
#     152     """Mean absolute error regression loss.
#     153
#     154     Read more in the :ref:`User Guide <mean_absolute_error>`.
#    (...)
#     202     0.85...
#     203     """
# --> 204     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     205         y_true, y_pred, multioutput
#     206     )
#     207     check_consistent_length(y_true, y_pred, sample_weight)
#     208     output_errors = np.average(np.abs(y_pred - y_true), weights=sample_weight, axis=0)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:101, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      99 check_consistent_length(y_true, y_pred)
#     100 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 101 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103 if y_true.ndim == 1:
#     104     y_true = y_true.reshape((-1, 1))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:959, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     953         raise ValueError(
#     954             "Found array with dim %d. %s expected <= 2."
#     955             % (array.ndim, estimator_name)
#     956         )
#     958     if force_all_finite:
# --> 959         _assert_all_finite(
#     960             array,
#     961             input_name=input_name,
#     962             estimator_name=estimator_name,
#     963             allow_nan=force_all_finite == "allow-nan",
#     964         )
#     966 if ensure_min_samples > 0:
#     967     n_samples = _num_samples(array)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
import matplotlib.pyplot as plt

merged_data["Residuals"] = merged_data["loadConsumption"] - merged_data["Final_Prediction"]

plt.figure(figsize=(12, 5))
plt.plot(merged_data["date"], merged_data["Residuals"], label="Residuals", color="red")
plt.axhline(0, linestyle="--", color="black")
plt.xlabel("date")
plt.ylabel("Prediction Error")
plt.title("Residuals Over Time")
plt.legend()
plt.show()

# %%
prophet = Prophet(weekly_seasonality=True, yearly_seasonality=True, daily_seasonality=False)
prophet.fit(prophet_data)
# Out:
# 22:12:22 - cmdstanpy - INFO - Chain [1] start processing
# 22:12:23 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Compute short-term residuals
merged_data["Short_Term_Residual"] = merged_data["loadConsumption"] - merged_data["Long_Term_Trend"]

# Ensure 'date' column is properly formatted
merged_data["date"] = pd.to_datetime(merged_data["date"])

# Prepare data for Prophet
prophet_data = merged_data[["date", "Short_Term_Residual", "DailyMeanTemperature", "DailyMeanWindspeed"]]
prophet_data = prophet_data.rename(columns={"date": "ds", "Short_Term_Residual": "y"})  # Correcting column names

# Initialize Prophet Model
prophet = Prophet()

# Add additional regressors
prophet.add_regressor("DailyMeanTemperature")
prophet.add_regressor("DailyMeanWindspeed")

# Fit Prophet Model
prophet.fit(prophet_data)

# Create future dataframe
future_dates = prophet.make_future_dataframe(periods=180)

# 🔹 **Fix: Extend Last Known Values to Match Future Data Length**
future_dates["DailyMeanTemperature"] = merged_data["DailyMeanTemperature"].iloc[-1]  # Repeat last known value
future_dates["DailyMeanWindspeed"] = merged_data["DailyMeanWindspeed"].iloc[-1]  # Repeat last known value

# Predict short-term variations
short_term_preds = prophet.predict(future_dates)

# Save predictions
merged_data["Final_Prediction"] = merged_data["Long_Term_Trend"] + short_term_preds["yhat"][: len(merged_data)].values

# Save to file
#merged_data.to_csv("/mnt/data/daily_final_predictions_with_regressors.csv", index=False)
# Out:
# 22:12:23 - cmdstanpy - INFO - Chain [1] start processing
# 22:12:24 - cmdstanpy - INFO - Chain [1] done processing

# %%
merged_data
# Out:
#            date  loadConsumption  DailyPrecipitation  MaxHourlyPrecipitation  \
# 0    2015-01-01      275667.0000                -0.1                    -0.1
# 1    2015-01-02      319026.0000                 4.3                     1.7
# 2    2015-01-03      313131.0000                 1.5                     0.5
# 3    2015-01-04      296832.0000                -0.1                    -0.1
# 4    2015-01-05      350937.0000                 0.0                     0.0
# ...         ...              ...                 ...                     ...
# 2917 2022-12-27      291327.2850                 1.0                     0.5
# 2918 2022-12-28      298608.1775                 4.3                     0.9
# 2919 2022-12-29      292450.9725                 3.5                     1.0
# 2920 2022-12-30      297210.1750                 5.2                     2.2
# 2921 2022-12-31      274811.7625                21.2                     3.6
#
#       HDMaxPrecipitation  DailyMeanTemperature  HourlyMinTemperature  \
# 0                      1                   3.0                    10
# 1                      3                   7.3                    44
# 2                     10                   3.8                    26
# 3                      1                   3.9                    -3
# 4                      1                   2.4                     9
# ...                  ...                   ...                   ...
# 2917                  23                   5.7                    39
# 2918                  18                   9.2                    60
# 2919                   2                   9.2                    65
# 2920                  24                   8.5                    46
# 2921                   5                  14.0                   104
#
#       HDMinTemperature  HourlyMaxTemperature  HDMaxTemperature  ...  \
# 0                    5                   4.7                24  ...
# 1                    1                  10.1                 8  ...
# 2                   17                   5.9                 1  ...
# 3                   21                   8.0                13  ...
# 4                   11                   3.8                24  ...
# ...                ...                   ...               ...  ...
# 2917                 6                   7.3                14  ...
# 2918                 1                  11.4                24  ...
# 2919                24                  11.7                 1  ...
# 2920                 7                  12.9                22  ...
# 2921                 5                  15.9                19  ...
#
#       HDMinMeanWindspeed  Month  Year  Week  WeekKey  day_of_week  \
# 0                      1      1  2015     1   201501     Thursday
# 1                     20      1  2015     1   201501       Friday
# 2                     17      1  2015     1   201501     Saturday
# 3                      1      1  2015     1   201501       Sunday
# 4                     22      1  2015     2   201502       Monday
# ...                  ...    ...   ...   ...      ...          ...
# 2917                   6     12  2022    52   202252      Tuesday
# 2918                   1     12  2022    52   202252    Wednesday
# 2919                  24     12  2022    52   202252     Thursday
# 2920                   3     12  2022    52   202252       Friday
# 2921                   5     12  2022    52   202252     Saturday
#
#       Long_Term_Trend  Short_Term_Residual  Final_Prediction    Residuals
# 0       275665.558841             1.441159     273776.939199  1105.300363
# 1       319024.332165             1.667835     317180.282275  1032.304570
# 2       313129.362983             1.637017     311415.546032   882.067093
# 3       296830.448193             1.551807     295152.602725   832.526697
# 4       350935.165337             1.834663     349067.755401  1009.965222
# ...               ...                  ...               ...          ...
# 2917    291513.835143          -186.550143     290533.872793    68.010331
# 2918    298799.389930          -191.212430     297790.555442   101.703287
# 2919    292638.242191          -187.269691     291609.116786   116.444763
# 2920    297400.492225          -190.317225     296415.271066    46.508141
# 2921    274987.737001          -175.974501     274131.265894   -82.802011
#
# [2922 rows x 24 columns]

# %%
# Ensure we only compare predictions for known dates
actual_values = merged_data["loadConsumption"]
predicted_values = merged_data["Final_Prediction"]

# Compute metrics
mae = mean_absolute_error(actual_values, predicted_values)
mse = mean_squared_error(actual_values, predicted_values)
rmse = np.sqrt(mse)
r2 = r2_score(actual_values, predicted_values)

# Print Metrics
print(f"📊 Model Evaluation Metrics:")
print(f"🔹 Mean Absolute Error (MAE): {mae:.2f}")
print(f"🔹 Mean Squared Error (MSE): {mse:.2f}")
print(f"🔹 Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"🔹 R² Score: {r2:.4f}")

# Save metrics to a file for reference
metrics_dict = {
    "MAE": mae,
    "MSE": mse,
    "RMSE": rmse,
    "R2_Score": r2
}

import json
with open("prophet_model_metrics.json", "w") as f:
    json.dump(metrics_dict, f)
# Out:
# 📊 Model Evaluation Metrics:
# 🔹 Mean Absolute Error (MAE): 1398.67
# 🔹 Mean Squared Error (MSE): 5520960.50
# 🔹 Root Mean Squared Error (RMSE): 2349.67
# 🔹 R² Score: 0.9949

# %%
merged_data
# Out:
#            date  loadConsumption  DailyPrecipitation  MaxHourlyPrecipitation  \
# 0    2015-01-01      275667.0000                -0.1                    -0.1
# 1    2015-01-02      319026.0000                 4.3                     1.7
# 2    2015-01-03      313131.0000                 1.5                     0.5
# 3    2015-01-04      296832.0000                -0.1                    -0.1
# 4    2015-01-05      350937.0000                 0.0                     0.0
# ...         ...              ...                 ...                     ...
# 2917 2022-12-27      291327.2850                 1.0                     0.5
# 2918 2022-12-28      298608.1775                 4.3                     0.9
# 2919 2022-12-29      292450.9725                 3.5                     1.0
# 2920 2022-12-30      297210.1750                 5.2                     2.2
# 2921 2022-12-31      274811.7625                21.2                     3.6
#
#       HDMaxPrecipitation  DailyMeanTemperature  HourlyMinTemperature  \
# 0                      1                   3.0                    10
# 1                      3                   7.3                    44
# 2                     10                   3.8                    26
# 3                      1                   3.9                    -3
# 4                      1                   2.4                     9
# ...                  ...                   ...                   ...
# 2917                  23                   5.7                    39
# 2918                  18                   9.2                    60
# 2919                   2                   9.2                    65
# 2920                  24                   8.5                    46
# 2921                   5                  14.0                   104
#
#       HDMinTemperature  HourlyMaxTemperature  HDMaxTemperature  ...  \
# 0                    5                   4.7                24  ...
# 1                    1                  10.1                 8  ...
# 2                   17                   5.9                 1  ...
# 3                   21                   8.0                13  ...
# 4                   11                   3.8                24  ...
# ...                ...                   ...               ...  ...
# 2917                 6                   7.3                14  ...
# 2918                 1                  11.4                24  ...
# 2919                24                  11.7                 1  ...
# 2920                 7                  12.9                22  ...
# 2921                 5                  15.9                19  ...
#
#       HDMinMeanWindspeed  Month  Year  Week  WeekKey  day_of_week  \
# 0                      1      1  2015     1   201501     Thursday
# 1                     20      1  2015     1   201501       Friday
# 2                     17      1  2015     1   201501     Saturday
# 3                      1      1  2015     1   201501       Sunday
# 4                     22      1  2015     2   201502       Monday
# ...                  ...    ...   ...   ...      ...          ...
# 2917                   6     12  2022    52   202252      Tuesday
# 2918                   1     12  2022    52   202252    Wednesday
# 2919                  24     12  2022    52   202252     Thursday
# 2920                   3     12  2022    52   202252       Friday
# 2921                   5     12  2022    52   202252     Saturday
#
#       Long_Term_Trend  Short_Term_Residual  Final_Prediction    Residuals
# 0       275665.558841             1.441159     273776.939199  1105.300363
# 1       319024.332165             1.667835     317180.282275  1032.304570
# 2       313129.362983             1.637017     311415.546032   882.067093
# 3       296830.448193             1.551807     295152.602725   832.526697
# 4       350935.165337             1.834663     349067.755401  1009.965222
# ...               ...                  ...               ...          ...
# 2917    291513.835143          -186.550143     290533.872793    68.010331
# 2918    298799.389930          -191.212430     297790.555442   101.703287
# 2919    292638.242191          -187.269691     291609.116786   116.444763
# 2920    297400.492225          -190.317225     296415.271066    46.508141
# 2921    274987.737001          -175.974501     274131.265894   -82.802011
#
# [2922 rows x 24 columns]

# %%
plt.plot(merged_data["date"], merged_data["loadConsumption"], label="Actual")
plt.plot(merged_data["date"], merged_data["Final_Prediction"], label="Predicted", linestyle="--")
plt.legend()
plt.show()
